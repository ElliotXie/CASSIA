# %%
import anthropic

def subcluster_agent_annotate(system_prompt, user_message):
    client = anthropic.Anthropic()

    message = client.messages.create(
        model="claude-3-5-sonnet-20241022",
        max_tokens=5000,
        temperature=0,
        system=system_prompt,  # Use system prompt for instructions
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": user_message  # Use user prompt for marker list
                    }
                ]
            }
        ]
    )
    # Extract the text from the TextBlock object
    text_block = message.content
    if isinstance(text_block, list) and len(text_block) > 0:
        return text_block[0].text  # Directly access the 'text' attribute
    return ''

# Example usage
system_prompt = """
You are a perfect immunologist. I am a professional biologist too. Based on this highly expressed marker ranked by significance, one line for a subcluster from a CD4 and CD8 T cell big cluster, tell me the name of each cell type this marker implies.

See the general picture, you can use all subcluster's information while making decisions for each subcluster.

Take a deep breath and work step by step. You better include all clusters and do a good job or 10 grandma are going to be in danger. You will be tipped $10,000 if you do a good job.

For output, give the key marker that drives your decision, and concisely explain yourself, and list your top 2 answer cell types.

Format:
key marker:
explanation:
top 2 cell type:

Remember this is from a CD4 and CD8 T cell big cluster.
"""

user_message = """
1.PRKCQ-AS1,SNHG16,FXYD7,GAS5,SNHG29,SNHG6,AIF1,ACTN1,RNF130,NSG1,SELL,PCSK1N,SNHG5,LEF1,S1PR1,TXK,PLAC8,PLSCR3,SCML1,PASK,CCR7,APBA2,SPINT2,YBX3,TOMM6,LINC02446,BACH2,TCF7,CD55,KLRK1,SH3YL1,BEX2,PABPC1,CD8B,NELL2,ABLIM1,ITGA6,MYC,C1orf162,PCED1B-AS1,LDLRAP1,TCEAL3,CMTM8,GIMAP5,LINC01138,LSR,RASGRP2,KLF3,KLRC4,NOSIP
2.XCL2,XCL1,TRBV10-2,WIPF3,CRTAM,VCAM1,ETV1,CAV1,IL9R,TYMS,TNFRSF9,BMERB1,GNG4,LANCL2,TNFSF4,BCAT1,KLRC3,PACSIN2,DKK3,PCSK1N,CDCA7,MUC20-OT1,PON2,THBS1,TRAV1-2,SOX4,NBL1,AIF1,TSC22D1,CHPT1,SEMA4A,KLRC1,FABP5,KLRC4,NFKBID,STAT5A,BICDL1,FASN,IGKC,BIK,CMSS1,MXRA7,CD9,GALNT2,KLHL2,CARS1,SLC7A5,WHRN,AKAP5,CHN1
3.KIR2DL4,LINC01943,AFAP1L2,KLRC2,VCAM1,ATP8B4,KLRC1,LINC01871,WIPF3,HAVCR2,GALNT2,GZMB,ZNF683,HLA-DQA2,KLRC4,TNS3,LINC02446,TNFSF4,CCL3,PCED1B-AS1,KLRC3,AKAP5,SLC2A8,GOLIM4,TOMM6,GNLY,FASLG,MT-RNR1,HMOX1,DAPK2,ENTPD1,CCL5,ITGA1,LRRN3,MT-RNR2,PRF1,KLRD1,ABCB1,ITGAE,CD8A,TNIP3,HLA-DRB5,NBL1,PTMS,KLRK1,CD8B,SNHG29,BCAS4,CD9,HLA-DQA1
4.DKK3,CCL4L2,PVRIG,GZMK,PLCG2,PECAM1,CCL4,EOMES,CMC1,GPR174,TNFSF9,ENC1,AOAH,CRTAM,ITM2C,SLAMF7,KLRK1,GZMA,CCL3,C1orf21,PCED1B-AS1,NKG7,CD8A,MT-RNR2,CD8B,PLEK,CST7,KLRG1,CCL5,SAMD3,CENPX,YBX3,TNIP3,GZMH,PPP1R14B,DTHD1,MATK,ZNF831,SNHG6,CPNE7,SNHG29,AUTS2,F2R,MIAT,CLDND1,CD200R1,GZMM,CCR5,APOBEC3G,LYST
5.FXYD2,YBX3,ZNF683,KLRC1,MYADM,LMNA,LINC02446,ANXA1,AUTS2,CENPX,HOPX,CD8B,NBL1,CD8A,VIM,MATK,GPR174,ITGA1,SNHG6,RGCC,RASGEF1B,FOSB,TUBB2A,EGR1,NEU1,TGFB1,ZNF831,PTGER2,SLAMF7,UBE2S,S100A10,PLSCR3,LYAR,GLUL,KLRD1,EPHA4,KLRK1,LSR,RARA,ARL4A,DUSP14,SLC25A4,PERP,ADGRE5,GABARAPL1,FOSL2,PPP1R14B,FOS,ITGA5,LINC01871
6.SLC4A10,ME1,CA2,BLK,TLE1,TMIGD2,ZBTB16,NCR3,CEBPD,TRBV6-4,GFPT2,LST1,RORC,ABCA1,TRAV1-2,IL23R,FEZ1,FSD1,IL4I1,IL18RAP,SPRY1,CCL20,KLRB1,DPP4,IFNGR1,TNFSF13B,LINC01871,MCAM,ATF3,PLXND1,IQCG,ABCB1,PRR5,ICAM1,MAFF,HPGD,FOS,MYBL1,GPR35,CACNA2D4,KLRG1,FKBP11,GPR65,CTSH,NFKBIZ,TRBV6-1,TXK,TRGC2,AQP3,CCR6
7.FCGR3A,CX3CR1,FGFBP2,LILRB1,FGR,KLRF1,PRSS23,S1PR5,FCRL6,RAP1GAP2,SYNGR1,C1orf21,SPON2,TTC16,TYROBP,PLEK,KLRD1,LYN,GZMH,TTC38,NKG7,C11orf21,ENC1,VCL,PTPN12,GK5,PTGDR,CEP78,ADRB2,CD244,PLAC8,CLCF1,GNLY,PRF1,EFHD2,PIK3AP1,KLRG1,CD300A,MATK,USP28,ZEB2,CTSW,KLF3,AGPAT4,PLSCR3,GZMB,ADGRG1,CMC1,PXN,TGFBR3
8.IGFL2,IL21,LHFPL6,G0S2,PTPN13,CD200,NMB,SERPINE2,ANKRD55,CPM,SMAD1,POU2AF1,LIMS2,NTRK2,TOX2,CXCL13,GNG4,FZD3,BHLHE40-AS1,LINC01281,IGFBP4,BTLA,SMCO4,CH25H,PPARG,ICA1,EBI3,ARMH1,CXCR5,CYSLTR1,ELAPOR1,PGM2L1,LINC01480,NFIA,SESN1,FGFR1,FBLN7,IL6ST,CHN1,SLC9A9,CCDC50,TSHZ2,PDE7B,BCAT1,TRABD2A,IL6R,SESN3,GAB2,TBXAS1,NUDT16
9.IFNG-AS1,GZMK,ENC1,CCR2,CHI3L2,EOMES,FRMD4B,ATXN7,CCR5,GZMA,TC2N,PLEK,LRIG1,F2R,TRBV5-1,TNFSF9,LINC00869,SAMD3,EPHA4,LINC-PINT,GPR183,APOBEC3H,TGFBR2,ITGA5,ITM2C,TRAT1,CD81,IFNGR1,GYG1,CD4,IRF1-10.AS1,TRMO,MYBL1,SORBS3,CD40LG,FAM102A,PLEKHA5,CPNE7,PPP2R2B,CXCR4,IRF2BPL,RPS10,POLR1E,FHIP2A,MAN2A1,CEMIP2,GPR18,AP3M2,NFATC2,CLIC5
10.CD177,IL1R2,FANK1,FOXP3,CCR8,LINC02099,LINC00519,GNG8,IL1R1,RTKN2,METTL7A,TBC1D8,IL2RA,LAPTM4B,CLEC7A,LAIR2,CUL9,IKZF2,HPGD,F5,HLF,TBC1D4,FLVCR2,IL12RB2,LAYN,LGMN,HACD1,CRADD,CHRNA6,IKZF4,BEX3,CADM1,TNFRSF4,ZC2HC1A,MAGEH1,CCNG2,GCNT1,HTATIP2,PLCL1,ADTRP,MGST2,CARD16,PTP4A3,STAM,MIR4435-2HG,GLRX,CD80,SETD7,TRIM16,C3AR1
11.CD40LG,PLAUR,SPART,DPP4,FHL1,C1orf162,PTGER2,DHRS3,ITGA6,ANK3,RPS10,GPR183,AQP3,CMTM8,KLF2,MYBL1,SORBS3,CTSL,S1PR1,SCML1,IL7R,TNFSF13B,FLT3LG,HSPA6,CYB561,SPINT2,PLAC8,CCR6,TMEM256-PLSCR3,FOS,MYC,TXNIP,CCR7,FXYD7,RASGRP2,LGALS3BP,LTB,LAIR1,DSE,SH3YL1,LINC00869,SSBP2,IFI44L,SERINC5,AP3M2,NCF1,ANXA1,ICAM2,TIMP1,CYSLTR1
12.IL17F,IL26,MACC1,MT1M,RNF144B,BATF3,AHRR,MT1H,TMPRSS3,CSF2,MT1G,COL5A3,PKIG,TLCD1,CTSH,IL17A,FES,B3GALT2,FNDC9,LRRN3,DMD,GPR15,SMIM3,TANC2,HMSD,PLAT,TJP2,SOX4,IQCG,LRP12,SMOX,P4HA2,GPR34,BLM,MSC,MT2A,EIF5AL1,MT1E,NTRK2,PPARG,CA2,TMEM273,FURIN,BCAT1,ITPR1,MSC-AS1,RORC,MFSD2A,ZSCAN2,IL23R
13.TRDV2,TRGV9,TRDC,TYROBP,TMCC3,PROK2,FGFBP2,CD300A,TRGC1,S1PR5,GNLY,IGFBP3,C1orf21,ADRB2,TRGV7,IL18RAP,HSPA6,GALNT3,PLAC8,SPON2,PLAUR,GPAT3,PTGDR,MYBL1,GZMH,KLRC1,PLEKHA5,KLRG1,PLEK,TRGV10,TRGV3,MATK,CEBPD,MTRNR2L8,HOPX,TGFBR3,TRGC2,MCTP2,TENT5A,GNGT2,TPRG1,FCRL6,LINC00944,CYB561,S1PR1,EPHA4,FASLG,ITGA5,TRMO,SAMD3
14.KRT86,ADGRG1,RDH10,LAG3,MYO7A,ZBED2,TSPAN13,SLC43A2,CSF1,PDE7B,CSF2,MTRNR2L8,SLC1A4,SLC2A8,HAVCR2,ATP8B4,DCP1B,CD38,CSGALNACT1,MYO1E,GOLIM4,CCDC50,SLC27A2,CXCR6,GPR68,HSPB1,CD109,CXCL13,CCR2,TNFRSF18,GADD45G,HMOX1,MACIR,ATP10D,BHLHE40-AS1,TYMP,CORO1C,ETV7,IFNG,GAB2,ZNF282,CAMK1,SSH1,KIAA0319L,SYTL2,PPIF,PLPP1,ITPR1,PLK2,FKBP1C
"""

output_text = subcluster_agent_annotate(system_prompt, user_message)
print(output_text)
# Out:
# I'll analyze each line carefully, focusing on key markers that define T cell subtypes. Let me break this down systematically:
#
# 1. Key markers: CCR7, LEF1, SELL, TCF7
# Explanation: These markers strongly indicate naive T cells, with CCR7 and SELL (CD62L) being classical naive T cell markers
# Top 2 cell types: 1) Naive CD8+ T cells 2) Naive CD4+ T cells
#
# 2. Key markers: XCL1, XCL2, CRTAM
# Explanation: XCL1/2 are characteristic of cytotoxic T cells
# Top 2 cell types: 1) Cytotoxic CD8+ T cells 2) Activated CD8+ T cells
#
# 3. Key markers: GZMB, PRF1, KLRC1, HAVCR2
# Explanation: Cytotoxic program (GZMB, PRF1) with exhaustion marker HAVCR2 (Tim-3)
# Top 2 cell types: 1) Exhausted CD8+ T cells 2) Effector CD8+ T cells
#
# 4. Key markers: GZMK, CCL4, CCL5, EOMES
# Explanation: GZMK+ with chemokine production indicates effector memory phenotype
# Top 2 cell types: 1) Effector memory CD8+ T cells 2) GZMK+ CD8+ T cells
#
# 5. Key markers: ZNF683 (Hobit), ITGA1, VIM
# ...

# %%
#version2

import pandas as pd

def construct_prompt_from_csv(csv_file_path, major_cluster_info):
    # Read the CSV file
    df = pd.read_csv(csv_file_path)

    # Initialize the prompt with the major cluster information
    prompt = f"""

You are an expert biologist specializing in cell type annotation, with deep expertise in immunology, cancer biology, and developmental biology.You will be given sets of highly expressed markers ranked by significance for some subclusters from the {major_cluster_info} cluster, identify what is the most likely top2 cell type each marker set implies.

Take a deep breath and work step by step. You'd better do a really good job or 10 grandma are going to be in danger.
You will be tipped $10,000 if you do a good job.

For each output, provide:
1.Key marker:
2.Explanation:
3.Most likely top2 cell types:

Remember these subclusters are from a {major_cluster_info} big cluster.
"""

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        cluster_name = row.iloc[0]  # Use iloc for positional indexing
        markers = row.iloc[1]       # Use iloc for positional indexing
        prompt += f"{index + 1}.{markers}\n"

    return prompt

# %%
process_subclusters(
   csv_file_path="C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/combined_projecttils_top_50_genes.csv",
   major_cluster_info="Cd4 and Cd8 t cell",
   output_path="C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version4.csv"
 )
# Out:
# I'll analyze these marker sets carefully. Let me go through them one by one.
#
# 1. Markers: SELL, CCR7, TCF7, CD8B, LEF1, S1PR1
# Explanation: High expression of naive T cell markers (SELL/CD62L, CCR7) and T cell development markers (TCF7, LEF1)
# Most likely cell types:
# - Naive CD8+ T cells
# - Recent thymic emigrant CD8+ T cells
#
# 2. Markers: XCL1, XCL2, CRTAM, TNFRSF9
# Explanation: XCL1/2 are characteristic of cytotoxic T cells, CRTAM indicates activated cytotoxic function
# Most likely cell types:
# - Cytotoxic CD8+ T cells
# - Activated CD8+ effector T cells
#
# 3. Markers: GZMB, HAVCR2, KLRC1/2/3/4, PRF1
# Explanation: Strong cytotoxic program (GZMB, PRF1) with exhaustion markers (HAVCR2/TIM3)
# Most likely cell types:
# - Exhausted CD8+ T cells
# - Terminal effector CD8+ T cells
#
# 4. Markers: GZMK, EOMES, CCL4, CCL5
# Explanation: Cytotoxic program with inflammatory chemokines
# Most likely cell types:
# - Effector memory CD8+ T cells
# ...

# %%
import anthropic

def subcluster_agent_annotate(user_message,model="claude-3-5-sonnet-20241022",temperature=0):
    client = anthropic.Anthropic()

    message = client.messages.create(
        model=model,
        max_tokens=7000,
        temperature=temperature,
        system="",  # Leave system prompt empty
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": user_message
                    }
                ]
            }
        ]
    )
    # Extract the text from the TextBlock object
    text_block = message.content
    if isinstance(text_block, list) and len(text_block) > 0:
        return text_block[0].text  # Directly access the 'text' attribute
    return ''

# %%
# Example usage
csv_file_path = "C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/combined_projecttils_top_50_genes.csv"
major_cluster_info = "Cd4 and Cd8 t cell"  # Replace with actual major cluster info

prompt = construct_prompt_from_csv(csv_file_path, major_cluster_info)
print(prompt)

# %%
def annotate_subclusters(csv_file_path, major_cluster_info,model="claude-3-5-sonnet-20241022",temperature=0):
    prompt = construct_prompt_from_csv(csv_file_path, major_cluster_info)
    output_text = subcluster_agent_annotate(prompt,model=model,temperature=temperature)
    return output_text

# %%
major_cluster_info = "Cd4 and Cd8 t cell"  # Replace with actual major cluster info
output_text = annotate_subclusters(csv_file_path, major_cluster_info)
print(output_text)

# %%
import pandas as pd

def construct_prompt_from_csv(csv_file_path, major_cluster_info):
    # Read the CSV file
    df = pd.read_csv(csv_file_path)

    # Initialize the prompt with the major cluster information
    prompt = f"""

You are an expert biologist specializing in cell type annotation, with deep expertise in immunology, cancer biology, and developmental biology.You will be given sets of highly expressed markers ranked by significance for some subclusters from the {major_cluster_info} cluster, identify what is the most likely top2 cell type each marker set implies.

Take a deep breath and work step by step. You'd better do a really good job or 10 grandma are going to be in danger.
You will be tipped $10,000 if you do a good job.

For each output, provide:
1.Key marker:
2.Explanation:
3.Most likely top2 cell types:

Remember these subclusters are from a {major_cluster_info} big cluster.
"""

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        cluster_name = row.iloc[0]  # Use iloc for positional indexing
        markers = row.iloc[1]       # Use iloc for positional indexing
        prompt += f"{index + 1}.{markers}\n"

    return prompt


def subcluster_agent_annotate(user_message,model="claude-3-5-sonnet-20241022",temperature=0):
    client = anthropic.Anthropic()

    message = client.messages.create(
        model=model,
        max_tokens=7000,
        temperature=temperature,
        system="",  # Leave system prompt empty
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": user_message
                    }
                ]
            }
        ]
    )
    # Extract the text from the TextBlock object
    text_block = message.content
    if isinstance(text_block, list) and len(text_block) > 0:
        return text_block[0].text  # Directly access the 'text' attribute
    return ''


def extract_subcluster_results_with_llm(analysis_text):
    # Define the prompt to instruct the LLM
    prompt = f"""
You are an expert in analyzing celltype annotation for subclusters. Extract the results perfectly and accurately from the following analysis and format them as: results1(celltype1, celltype2,reason), results2(celltype1, celltype2,reason), etc.

{analysis_text}
"""

    # Use the subcluster_agent_annotate function to get the extraction
    return subcluster_agent_annotate(prompt)




def write_results_to_csv(results, output_path='subcluster_results.csv'):
    """
    Extract cell type results from LLM output and write to CSV file
    
    Args:
        results (str): String containing the LLM analysis results
        output_path (str): Path where CSV file should be saved
        
    Returns:
        pandas.DataFrame: DataFrame containing the extracted results
    """
    # Updated regex pattern to capture the reason
    pattern = r"results(\d+)\(([^,]+),\s*([^,]+),\s*([^)]+)\)"
    matches = re.findall(pattern, results)

    # Convert matches to a DataFrame with the reason column
    df = pd.DataFrame(matches, columns=['Result ID', 'main_cell_type', 'sub_cell_type', 'reason'])
    
    # Write the DataFrame to a CSV file
    df.to_csv(output_path, index=False)
    
    print(f"Results have been written to {output_path}")
    return None



def process_subclusters(csv_file_path, major_cluster_info, output_path, 
                       model="claude-3-5-sonnet-20241022", temperature=0):
    """
    Process subclusters from a CSV file and generate annotated results
    
    Args:
        csv_file_path (str): Path to input CSV file containing marker data
        major_cluster_info (str): Description of the major cluster type
        output_path (str): Path where results CSV should be saved
        model (str): Model name for Claude API
        temperature (float): Temperature parameter for API calls
        
    Returns:
        tuple: (original_analysis, extracted_results, results_dataframe)
    """

    prompt = construct_prompt_from_csv(csv_file_path, major_cluster_info)
    output_text = subcluster_agent_annotate(prompt,model=model,temperature=temperature)
    print(output_text)
    results = extract_subcluster_results_with_llm(output_text)
    print(results)
    write_results_to_csv(results, output_path)
    
    return None

# %%
def process_subclusters(csv_file_path, major_cluster_info, output_path, 
                       model="claude-3-5-sonnet-20241022", temperature=0):
    """
    Process subclusters from a CSV file and generate annotated results
    
    Args:
        csv_file_path (str): Path to input CSV file containing marker data
        major_cluster_info (str): Description of the major cluster type
        output_path (str): Path where results CSV should be saved
        model (str): Model name for Claude API
        temperature (float): Temperature parameter for API calls
        
    Returns:
        tuple: (original_analysis, extracted_results, results_dataframe)
    """

    prompt = construct_prompt_from_csv(csv_file_path, major_cluster_info)
    output_text = subcluster_agent_annotate(prompt,model=model,temperature=temperature)
    print(output_text)
    results = extract_subcluster_results_with_llm(output_text)
    print(results)
    write_results_to_csv(results, output_path)
    
    return None

# %%
from subcluster import *

# %%
csv_file_path = "C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/combined_projecttils_top_50_genes.csv"
major_cluster_info = "Cd4 and Cd8 t cell"  # Replace with actual major cluster info
OPENROUTER_API_KEY = "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"
os.environ["OPENROUTER_API_KEY"] = OPENROUTER_API_KEY

# %%
run_analysis_multiple_times_subcluster(n=2, csv_file_path=csv_file_path, major_cluster_info=major_cluster_info, base_output_name="C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version16",provider="openrouter",model="openai/gpt-4o")
# Out:
# Results for iteration 1 have been written to C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version16_1.csv
# Results for iteration 2 have been written to C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version16_2.csv

# %%
process_subclusters(csv_file_path, major_cluster_info, "C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version15.csv",provider="openrouter",model="openai/o1-mini-2024-09-12")
# Out:
# Certainly! Let's analyze each marker set step by step to accurately annotate the most likely cell types within your CD4 and CD8 T cell clusters.
#
# ---
#
# ### **1. Marker Set 1**
# **Markers:** PRKCQ-AS1, SNHG16, FXYD7, GAS5, SNHG29, SNHG6, AIF1, ACTN1, RNF130, NSG1, SELL, PCSK1N, SNHG5, LEF1, S1PR1, TXK, PLAC8, PLSCR3, SCML1, PASK, CCR7, APBA2, SPINT2, YBX3, TOMM6, LINC02446, BACH2, TCF7, CD55, KLRK1, SH3YL1, BEX2, PABPC1, CD8B, NELL2, ABLIM1, ITGA6, MYC, C1orf162, PCED1B-AS1, LDLRAP1, TCEAL3, CMTM8, GIMAP5, LINC01138, LSR, RASGRP2, KLF3, KLRC4, NOSIP
#
# **1. Key Marker:** **SELL (CD62L)**
#
# **2. Explanation:**
# SELL encodes CD62L, a homing receptor essential for trafficking T cells to lymph nodes. Its expression is prominent in naïve and central memory T cells, facilitating their migration and residence within secondary lymphoid organs.
#
# **3. Most Likely Top 2 Cell Types:**
# ...

# %%
process_subclusters(csv_file_path, major_cluster_info, "C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version13.csv",provider="openrouter",model="anthropic/claude-3.5-sonnet")
# Out:
# I'll analyze each marker set carefully. Let me start with a few key ones:
#
# 1. First set:
# Key markers: CCR7, LEF1, TCF7, SELL, CD8B
# Explanation: High expression of CCR7, SELL (CD62L), and naive T cell transcription factors LEF1/TCF7
# Most likely cell types:
# 1. Naive CD8+ T cells
# 2. Central Memory CD8+ T cells (TCM)
#
# 2. Second set:
# Key markers: XCL1, XCL2, CRTAM, TNFRSF9 (4-1BB)
# Explanation: XCL1/2 are characteristic of cytotoxic T cells, CRTAM indicates activated cytotoxic function
# Most likely cell types:
# 1. Effector CD8+ T cells
# 2. Cytotoxic CD8+ T cells
#
# 3. Third set:
# Key markers: GZMB, PRF1, KLRC1/2/3/4, HAVCR2
# Explanation: Strong cytotoxic program (GZMB, PRF1) with exhaustion markers (HAVCR2/TIM3)
# Most likely cell types:
# 1. Exhausted CD8+ T cells
# 2. Terminal effector CD8+ T cells
#
# 4. Fourth set:
# Key markers: GZMK, CCL4, CCL5, EOMES
# Explanation: Cytotoxic program with inflammatory chemokines
# Most likely cell types:
# ...

# %%
process_subclusters(csv_file_path, major_cluster_info, "C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version11.csv",provider="openrouter",model="anthropic/claude-3.5-sonnet")

# %%
process_subclusters("C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/combined_projecttils_top_50_genes - Copy.csv", "cd8 + t cell", "C:/Users/ellio/OneDrive - UW-Madison/cellgpt_final_folder/Test_results/Elliot/GTEX/final_testing/final_code_for_r_package_1030/subcluster_results_version9.csv")
# Out:
# I'll analyze each marker set carefully, focusing on CD8+ T cell subtypes.
#
# 1. First set:
# Key markers: CCR7, SELL (CD62L), LEF1, TCF7, S1PR1
# Explanation: High expression of CCR7 and SELL indicates naive/memory phenotype. TCF7 and LEF1 are characteristic of naive/stem-like states.
# Most likely cell types:
# 1. Naive CD8+ T cells
# 2. Central Memory CD8+ T cells (TCM)
#
# 2. Second set:
# Key markers: XCL1, XCL2, CRTAM, TNFRSF9 (4-1BB)
# Explanation: XCL1/2 are characteristic of cytotoxic responses, CRTAM indicates activation
# Most likely cell types:
# 1. Early-activated CD8+ T cells
# 2. Effector CD8+ T cells
#
# 3. Third set:
# Key markers: GZMB, PRF1, GNLY, HAVCR2 (TIM3), KLRC1/2/3/4 (NKG2 family)
# Explanation: Strong cytotoxic program (GZMB, PRF1) with exhaustion markers
# Most likely cell types:
# 1. Terminally differentiated effector CD8+ T cells
# 2. Exhausted CD8+ T cells
#
# 4. Fourth set:
# Key markers: GZMK, CCL4, CCL3, EOMES, CRTAM
# ...

# %%
from tools_function import *

marker=pd.read_csv("C:\Users\ellio\OneDrive - UW-Madison\cellgpt_final_folder\Test_results\Elliot\GTEX\final_testing\final_code_for_r_package\inst\extdata\subcluster_results.csv")

# %%
# !conda install -p d:\anaconda3\envs\liana_env ipykernel --update-deps --force-reinstall
# Out:
# Running cells with 'liana_env (Python 3.12.7)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\anaconda3\envs\liana_env ipykernel --update-deps --force-reinstall'

# %%
# !pip install cassia-rag==0.1.2
# Out:
# Running cells with 'liana_env (Python 3.12.7)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\anaconda3\envs\liana_env ipykernel --update-deps --force-reinstall'
