# %% [markdown]
# # CASSIA Analysis Tutorial
#
# This Python Notebook demonstrates a complete workflow using CASSIA for cell type annotation of single-cell RNA sequencing data. We'll analyze an intestinal cell dataset containing six distinct populations:
#
# 1.monocyte
#
# 2.plasma cells
#
# 3.cd8-positive, alpha-beta t cell
#
# 4.transit amplifying cell of large intestine
#
# 5.intestinal enteroendocrine cell
#
# 6.intestinal crypt stem cell

# %% [markdown]
# ## Setup and Environment Preparation
#
# First, let's install and import the required packages:

# %%
import CASSIA
print(CASSIA.__file__)
print(CASSIA.__version__)

processed_markers = CASSIA.loadmarker(marker_type="processed")
unprocessed_markers = CASSIA.loadmarker(marker_type="unprocessed")
subcluster_results = CASSIA.loadmarker(marker_type="subcluster_results")

# List available marker sets
available_markers = CASSIA.list_available_markers()
print(available_markers)
# Out:
# d:\anaconda3\envs\cassia_env\lib\site-packages\CASSIA\__init__.py
# 0.2.21
# ['processed', 'subcluster_results', 'unprocessed']

# %%
import os


custom_base_url = "https://api.deepseek.com"
custom_model = "deepseek-chat"

CASSIA.set_api_key("sk-f7c54e95a5e040589f41d83553b55861", provider="https://api.deepseek.com")
print("API key set:", os.getenv("CUSTERMIZED_API_KEY") is not None)

# %% [markdown]
# ## Fast Mode

# %%
# Run the CASSIA pipeline in fast mode
CASSIA.runCASSIA_pipeline(
    output_file_name = "FastAnalysisResults",
    tissue = "large intestine",
    species = "human",
    marker_path = unprocessed_markers,
    max_workers = 6,  # Matches the number of clusters in dataset
    annotation_model = "google/gemini-2.5-flash-preview-05-20", #openai/gpt-4o-2024-11-20
    annotation_provider = "openrouter",
    score_model = "google/gemini-2.5-flash-preview-05-20",
    score_provider = "openrouter",
    score_threshold = 98,
    annotationboost_model="google/gemini-2.5-flash-preview-05-20",
    annotationboost_provider="openrouter",
    ranking_method="p_val_adj"
)
# Out:
# Created main folder: CASSIA_large_intestine_human_20250622_151232
# Created subfolder: CASSIA_large_intestine_human_20250622_151232\01_annotation_results
# Created subfolder: CASSIA_large_intestine_human_20250622_151232\02_reports
# Created subfolder: CASSIA_large_intestine_human_20250622_151232\03_boost_analysis
#
# === Starting cell type analysis ===
# Processing input dataframe to get top markers
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing monocyte...
#
# Analyzing plasma cell...
#
# Analyzing transit amplifying cell of large intestine...
# Analysis for plasma cell completed.
# Analysis for cd8-positive, alpha-beta t cell completed.
# Analysis for intestinal crypt stem cell completed.
# Analysis for transit amplifying cell of large intestine completed.
# Analysis for monocyte completed.
# Analysis for intestinal enteroendocrine cell completed.
# All analyses completed. Results saved to 'FastAnalysisResults'.
# Two CSV files have been created:
# 1. FastAnalysisResults_full.csv (full data)
# 2. FastAnalysisResults_summary.csv (summary data)
# ✓ Cell type analysis completed
# Copied full results to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults_full.csv
# Copied summary results to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults_summary.csv
#
# === Starting annotation merging ===
# Sorting CSV by True Cell Type before merging...
# Processing all three detail levels in parallel...
# Completed processing for detailed detail level
# Completed processing for broad detail level
# Completed processing for very_detailed detail level
# Combined results saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults_merged.csv
# ✓ Annotations merged and saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults_merged.csv
#
# === Starting scoring process ===
# Starting scoring process with 6 workers using openrouter (google/gemini-2.5-flash-preview-05-20)...
# Processed row 2: Score = 98
# Processed row 3: Score = 98
# Processed row 4: Score = 95
# Processed row 6: Score = 98
# Processed row 1: Score = 98
# Processed row 5: Score = 98
#
# Scoring completed!
#
# Summary:
# Total rows: 6
# Successfully scored: 6
# Failed/Skipped: 0
# ✓ Scoring process completed
#
# === Creating final combined results ===
# ✓ Final combined results saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults_FINAL_RESULTS.csv
#
# === Generating main reports ===
# Report saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\report_cd8-positive alpha-beta t cell.html
# Report saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\report_intestinal crypt stem cell.html
# Report saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\report_intestinal enteroendocrine cell.html
# Report saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\report_monocyte.html
# Report saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\report_plasma cell.html
# Report saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\report_transit amplifying cell of large intestine.html
# Index page saved to CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults.html
# Moved HTML report FastAnalysisResults.html to reports folder
# Moved HTML report report_cd8-positive alpha-beta t cell.html to reports folder
# Moved HTML report report_intestinal crypt stem cell.html to reports folder
# Moved HTML report report_intestinal enteroendocrine cell.html to reports folder
# Moved HTML report report_monocyte.html to reports folder
# Moved HTML report report_plasma cell.html to reports folder
# Moved HTML report report_transit amplifying cell of large intestine.html to reports folder
# ✓ Main reports generated
#
# === Analyzing low-scoring clusters ===
# Found 1 clusters with scores below 98:
# ['monocyte']
#
# === Starting boost annotation for low-scoring clusters ===
# Processing low score cluster: monocyte
# Using summarization agent to process conversation history for cluster monocyte
# Conversation history summarized using openrouter (12279 -> 1563 characters)
# Using conversation history for cluster monocyte (mode: final, 1563 characters)
# Iteration 1 completed.
# Iteration 2 completed.
# Iteration 3 completed.
# Final annotation completed in iteration 4.
# Raw conversation text saved to CASSIA_large_intestine_human_20250622_151232\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250622_151232\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_raw_conversation.txt
# HTML report saved to CASSIA_large_intestine_human_20250622_151232\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250622_151232\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250622_151232\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_summary.html
# ✓ Boost annotation completed
#
# === Organizing intermediate files ===
# Moved FastAnalysisResults_full.csv to intermediate_files folder
# Moved FastAnalysisResults_summary.csv to intermediate_files folder
# Moved FastAnalysisResults_sorted_full.csv to intermediate_files folder
# Moved FastAnalysisResults_scored.csv to intermediate_files folder
# Moved FastAnalysisResults_merged.csv to intermediate_files folder
# ✓ Intermediate files organized
# Removed original file: FastAnalysisResults_full.csv
# Removed original file: FastAnalysisResults_summary.csv
#
# === Cell type analysis pipeline completed ===
# All results have been organized in the 'CASSIA_large_intestine_human_20250622_151232' folder:
#   📊 MAIN RESULTS: CASSIA_large_intestine_human_20250622_151232\01_annotation_results\FastAnalysisResults_FINAL_RESULTS.csv
#   📁 HTML Reports: CASSIA_large_intestine_human_20250622_151232\02_reports
#   🔍 Annotation Boost Results: CASSIA_large_intestine_human_20250622_151232\03_boost_analysis
#   📂 Intermediate Files: CASSIA_large_intestine_human_20250622_151232\01_annotation_results\intermediate_files
#
# ✅ Your final results are in: FastAnalysisResults_FINAL_RESULTS.csv

# %%
# Run the CASSIA pipeline in fast mode
CASSIA.runCASSIA_pipeline(
    output_file_name = "FastAnalysisResults",
    tissue = "large intestine",
    species = "human",
    marker_path = unprocessed_markers,
    max_workers = 6,  # Matches the number of clusters in dataset
    annotation_model = "deepseek-chat", #openai/gpt-4o-2024-11-20
    annotation_provider = custom_base_url,
    score_model = "deepseek-chat",
    score_provider = custom_base_url,
    score_threshold = 98,
    annotationboost_model="deepseek-chat",
    annotationboost_provider=custom_base_url,
    ranking_method="p_val_adj"
)
# Out:
# Created main folder: CASSIA_large_intestine_human_20250611_000057
# Created subfolder: CASSIA_large_intestine_human_20250611_000057\01_annotation_results
# Created subfolder: CASSIA_large_intestine_human_20250611_000057\02_reports
# Created subfolder: CASSIA_large_intestine_human_20250611_000057\03_boost_analysis
#
# === Starting cell type analysis ===
# Processing input dataframe to get top markers
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing monocyte...
#
# Analyzing plasma cell...
#
# Analyzing transit amplifying cell of large intestine...
# Analysis for cd8-positive, alpha-beta t cell completed.
# Analysis for intestinal enteroendocrine cell completed.
# Analysis for intestinal crypt stem cell completed.
# Analysis for plasma cell completed.
# Analysis for transit amplifying cell of large intestine completed.
# Analysis for monocyte completed.
# All analyses completed. Results saved to 'FastAnalysisResults'.
# Two CSV files have been created:
# 1. FastAnalysisResults_full.csv (full data)
# 2. FastAnalysisResults_summary.csv (summary data)
# ✓ Cell type analysis completed
# Copied full results to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\FastAnalysisResults_full.csv
# Copied summary results to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\FastAnalysisResults_summary.csv
#
# === Starting annotation merging ===
# Sorting CSV by True Cell Type before merging...
# Processing all three detail levels in parallel...
# Completed processing for broad detail level
# Completed processing for detailed detail level
# Completed processing for very_detailed detail level
# Combined results saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\FastAnalysisResults_merged.csv
# ✓ Annotations merged and saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\FastAnalysisResults_merged.csv
#
# === Starting scoring process ===
# Starting scoring process with 6 workers using https://api.deepseek.com (deepseek-chat)...
# Processed row 4: Score = 92
# Processed row 2: Score = 92
# Processed row 1: Score = 92
# Processed row 3: Score = 95
# Processed row 5: Score = 95
# Processed row 6: Score = 95
#
# Scoring completed!
#
# Summary:
# Total rows: 6
# Successfully scored: 6
# Failed/Skipped: 0
# ✓ Scoring process completed
#
# === Creating final combined results ===
# ✓ Final combined results saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\FastAnalysisResults_FINAL_RESULTS.csv
#
# === Generating main reports ===
# Report saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\report_cd8-positive alpha-beta t cell.html
# Report saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\report_intestinal crypt stem cell.html
# Report saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\report_intestinal enteroendocrine cell.html
# Report saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\report_monocyte.html
# Report saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\report_plasma cell.html
# Report saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\report_transit amplifying cell of large intestine.html
# Index page saved to CASSIA_large_intestine_human_20250611_000057\01_annotation_results\FastAnalysisResults.html
# Moved HTML report FastAnalysisResults.html to reports folder
# Moved HTML report report_cd8-positive alpha-beta t cell.html to reports folder
# Moved HTML report report_intestinal crypt stem cell.html to reports folder
# Moved HTML report report_intestinal enteroendocrine cell.html to reports folder
# Moved HTML report report_monocyte.html to reports folder
# Moved HTML report report_plasma cell.html to reports folder
# Moved HTML report report_transit amplifying cell of large intestine.html to reports folder
# ✓ Main reports generated
#
# === Analyzing low-scoring clusters ===
# Found 6 clusters with scores below 98:
# ['cd8-positive, alpha-beta t cell', 'intestinal crypt stem cell', 'intestinal enteroendocrine cell', 'monocyte', 'plasma cell', 'transit amplifying cell of large intestine']
#
# === Starting boost annotation for low-scoring clusters ===
# Processing low score cluster: cd8-positive, alpha-beta t cell
# Using summarization agent to process conversation history for cluster cd8-positive, alpha-beta t cell
# Conversation history summarized using https://api.deepseek.com (5362 -> 1781 characters)
# Using conversation history for cluster cd8-positive, alpha-beta t cell (mode: final, 1781 characters)
# Final annotation completed in iteration 1.
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\cd8-positive alpha-beta t cell\FastAnalysisResults_cd8-positive alpha-beta t cell_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\cd8-positive alpha-beta t cell\FastAnalysisResults_cd8-positive alpha-beta t cell_boosted_raw_conversation.txt
# HTML report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\cd8-positive alpha-beta t cell\FastAnalysisResults_cd8-positive alpha-beta t cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\cd8-positive alpha-beta t cell\FastAnalysisResults_cd8-positive alpha-beta t cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\cd8-positive alpha-beta t cell\FastAnalysisResults_cd8-positive alpha-beta t cell_boosted_summary.html
# Processing low score cluster: intestinal crypt stem cell
# Using summarization agent to process conversation history for cluster intestinal crypt stem cell
# Conversation history summarized using https://api.deepseek.com (6374 -> 1910 characters)
# Using conversation history for cluster intestinal crypt stem cell (mode: final, 1910 characters)
# Final annotation completed in iteration 1.
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal crypt stem cell\FastAnalysisResults_intestinal crypt stem cell_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal crypt stem cell\FastAnalysisResults_intestinal crypt stem cell_boosted_raw_conversation.txt
# HTML report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal crypt stem cell\FastAnalysisResults_intestinal crypt stem cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal crypt stem cell\FastAnalysisResults_intestinal crypt stem cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal crypt stem cell\FastAnalysisResults_intestinal crypt stem cell_boosted_summary.html
# Processing low score cluster: intestinal enteroendocrine cell
# Using summarization agent to process conversation history for cluster intestinal enteroendocrine cell
# Conversation history summarized using https://api.deepseek.com (5887 -> 1797 characters)
# Using conversation history for cluster intestinal enteroendocrine cell (mode: final, 1797 characters)
# Final annotation completed in iteration 1.
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal enteroendocrine cell\FastAnalysisResults_intestinal enteroendocrine cell_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal enteroendocrine cell\FastAnalysisResults_intestinal enteroendocrine cell_boosted_raw_conversation.txt
# HTML report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal enteroendocrine cell\FastAnalysisResults_intestinal enteroendocrine cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal enteroendocrine cell\FastAnalysisResults_intestinal enteroendocrine cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\intestinal enteroendocrine cell\FastAnalysisResults_intestinal enteroendocrine cell_boosted_summary.html
# Processing low score cluster: monocyte
# Using summarization agent to process conversation history for cluster monocyte
# Conversation history summarized using https://api.deepseek.com (7929 -> 1856 characters)
# Using conversation history for cluster monocyte (mode: final, 1856 characters)
# Final annotation completed in iteration 1.
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_raw_conversation.txt
# HTML report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\monocyte\FastAnalysisResults_monocyte_boosted_summary.html
# Processing low score cluster: plasma cell
# Using summarization agent to process conversation history for cluster plasma cell
# Conversation history summarized using https://api.deepseek.com (6660 -> 1957 characters)
# Using conversation history for cluster plasma cell (mode: final, 1957 characters)
# Final annotation completed in iteration 1.
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\plasma cell\FastAnalysisResults_plasma cell_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\plasma cell\FastAnalysisResults_plasma cell_boosted_raw_conversation.txt
# HTML report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\plasma cell\FastAnalysisResults_plasma cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\plasma cell\FastAnalysisResults_plasma cell_boosted_summary.html
# Summary report saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\plasma cell\FastAnalysisResults_plasma cell_boosted_summary.html
# Processing low score cluster: transit amplifying cell of large intestine
# Using summarization agent to process conversation history for cluster transit amplifying cell of large intestine
# Conversation history summarized using https://api.deepseek.com (6704 -> 2088 characters)
# Using conversation history for cluster transit amplifying cell of large intestine (mode: final, 2088 characters)
# Final annotation completed in iteration 1.
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\transit amplifying cell of large intestine\FastAnalysisResults_transit amplifying cell of large intestine_boosted_raw_conversation.txt
# Raw conversation text saved to CASSIA_large_intestine_human_20250611_000057\03_boost_analysis\transit amplifying cell of large intestine\FastAnalysisResults_transit amplifying cell of large intestine_boosted_raw_conversation.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Run the CASSIA pipeline in fast mode
# ----> 2 CASSIA.runCASSIA_pipeline(
#       3     output_file_name = "FastAnalysisResults",
#       4     tissue = "large intestine",
#       5     species = "human",
#       6     marker_path = unprocessed_markers,
#       7     max_workers = 6,  # Matches the number of clusters in dataset
#       8     annotation_model = "deepseek-chat", #openai/gpt-4o-2024-11-20
#       9     annotation_provider = custom_base_url,
#      10     score_model = "deepseek-chat",
#      11     score_provider = custom_base_url,
#      12     score_threshold = 98,
#      13     annotationboost_model="deepseek-chat",
#      14     annotationboost_provider=custom_base_url,
#      15     ranking_method="p_val_adj"
#      16 )
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\CASSIA\tools_function.py:1740, in runCASSIA_pipeline(output_file_name, tissue, species, marker_path, max_workers, annotation_model, annotation_provider, score_model, score_provider, annotationboost_model, annotationboost_provider, score_threshold, additional_info, max_retries, merge_annotations, merge_model, conversation_history_mode, ranking_method, ascending)
#    1736     major_cluster_info = f"{species} {tissue}"
#    1738     # Run annotation boost - use original cluster name for data lookup, but sanitized name for output file
#    1739     # NOTE: Using the raw_full_csv path to ensure the CSV can be found
# -> 1740     runCASSIA_annotationboost(
#    1741         full_result_path=raw_full_csv,  # This is in the annotation_results_folder
#    1742         marker=marker_path,
#    1743         cluster_name=original_cluster_name,
#    1744         major_cluster_info=major_cluster_info,
#    1745         output_name=cluster_output_name,
#    1746         num_iterations=5,
#    1747         model=annotationboost_model,
#    1748         provider=annotationboost_provider,
#    1749         temperature=0,
#    1750         conversation_history_mode=conversation_history_mode
#    1751     )
#    1752 except IndexError:
#    1753     print(f"Error in pipeline: No data found for cluster: {original_cluster_name}")
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\CASSIA\tools_function.py:989, in runCASSIA_annotationboost(full_result_path, marker, cluster_name, major_cluster_info, output_name, num_iterations, model, provider, temperature, conversation_history_mode)
#     986     except ImportError:
#     987         raise ImportError("Could not import annotation_boost module.")
# --> 989 return run_annotationboost(
#     990     full_result_path=full_result_path,
#     991     marker=marker,
#     992     cluster_name=cluster_name,
#     993     major_cluster_info=major_cluster_info,
#     994     output_name=output_name,
#     995     num_iterations=num_iterations,
#     996     model=model,
#     997     provider=provider,
#     998     temperature=temperature,
#     999     conversation_history_mode=conversation_history_mode
#    1000 )
#
# File d:\newgit\CASSIA\CASSIA_python\CASSIA\annotation_boost.py:1055, in runCASSIA_annotationboost(full_result_path, marker, cluster_name, major_cluster_info, output_name, num_iterations, model, provider, temperature, conversation_history_mode)
#    1052     print(f"Raw conversation text saved to {raw_text_path}")
#    1054     # Generate the summary report
# -> 1055     summary_report_path = generate_summary_report(conversation_without_prompt, summary_report_path)
#    1056     print(f"Summary report saved to {summary_report_path}")
#    1057 except Exception as e:
#
# File d:\newgit\CASSIA\CASSIA_python\CASSIA\annotation_boost.py:957, in generate_summary_report(conversation_history, output_filename)
#     897 prompt = f"""You are a specialized scientific report generator focusing on gene expression analysis.
#     898 I will provide you a raw conversation history from a cell type annotation tool called CASSIA, which conducts iterative gene expression analysis.
#     899
#    (...)
#     953 {full_conversation}
#     954 """
#     956 # Use the call_llm function to generate the summary
# --> 957 summary = call_llm(
#     958     prompt=prompt,
#     959     provider="openrouter",  # Using OpenRouter as the provider
#     960     model="google/gemini-2.5-flash-preview",  # Using Gemini 2.5 Flash model
#     961     temperature=0.3,      # Low temperature for more consistent output
#     962     max_tokens=4000
#     963 )
#     965 # Convert to HTML and save
#     966 html_path = format_summary_to_html(summary, output_filename)
#
# File d:\newgit\CASSIA\CASSIA_python\CASSIA\llm_utils.py:186, in call_llm(prompt, provider, model, api_key, temperature, max_tokens, system_prompt, additional_params)
#     173 headers = {
#     174     "Authorization": f"Bearer {api_key}",
#     175     "Content-Type": "application/json"
#     176 }
#     178 data = {
#     179     "model": model,
#     180     "messages": messages,
#    (...)
#     183     **additional_params
#     184 }
# --> 186 response = requests.post(url, headers=headers, data=json.dumps(data))
#     187 response.raise_for_status()
#     189 return response.json()["choices"][0]["message"]["content"]
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\urllib3\response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1047 """
#    1048 A generator wrapper for the read() method. A call will block until
#    1049 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1060     'content-encoding' header.
#    1061 """
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\urllib3\response.py:1219, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1216     amt = None
#    1218 while True:
# -> 1219     self._update_chunk_length()
#    1220     if self.chunk_left == 0:
#    1221         break
#
# File d:\anaconda3\envs\cassia_env\lib\site-packages\urllib3\response.py:1138, in HTTPResponse._update_chunk_length(self)
#    1136 if self.chunk_left is not None:
#    1137     return None
# -> 1138 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139 line = line.split(b";", 1)[0]
#    1140 try:
#
# File d:\anaconda3\envs\cassia_env\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File d:\anaconda3\envs\cassia_env\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File d:\anaconda3\envs\cassia_env\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
output_name="intestine_detailed"

# %%
# Run the CASSIA pipeline in fast mode
CASSIA.runCASSIA_pipeline(
    output_file_name = "FastAnalysisResults",
    tissue = "large intestine",
    species = "human",
    marker_path = unprocessed_markers,
    max_workers = 6,  # Matches the number of clusters in dataset
    annotation_model = "google/gemini-2.5-flash-preview-05-20", #openai/gpt-4o-2024-11-20
    annotation_provider = "openrouter",
    score_model = "google/gemini-2.5-flash-preview-05-20",
    score_provider = "openrouter",
    score_threshold = 98,
    annotationboost_model="google/gemini-2.5-flash-preview-05-20",
    annotationboost_provider="openrouter"
)
# Out:
# Created main folder: CASSIA_large_intestine_human_20250603_004726
# Created subfolder: CASSIA_large_intestine_human_20250603_004726\01_annotation_results
# Created subfolder: CASSIA_large_intestine_human_20250603_004726\02_reports
# Created subfolder: CASSIA_large_intestine_human_20250603_004726\03_boost_analysis
#
# === Starting cell type analysis ===
# Processing input dataframe to get top markers
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing monocyte...
#
# Analyzing plasma cell...
#
# Analyzing transit amplifying cell of large intestine...
# Analysis for intestinal crypt stem cell completed.
#
# Analysis for monocyte completed.
#
# Analysis for transit amplifying cell of large intestine completed.
#
# Analysis for plasma cell completed.
#
# Analysis for intestinal enteroendocrine cell completed.
#
# Analysis for cd8-positive, alpha-beta t cell completed.
#
# All analyses completed. Results saved to 'FastAnalysisResults'.
# Two CSV files have been created:
# 1. FastAnalysisResults_full.csv (full data)
# 2. FastAnalysisResults_summary.csv (summary data)
# ✓ Cell type analysis completed
# Copied full results to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\FastAnalysisResults_full.csv
# Copied summary results to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\FastAnalysisResults_summary.csv
#
# === Starting annotation merging ===
# Sorting CSV by True Cell Type before merging...
# Processing all three detail levels in parallel...
# Completed processing for detailed detail level
# Completed processing for very_detailed detail level
# Completed processing for broad detail level
# Combined results saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\FastAnalysisResults_merged.csv
# ✓ Annotations merged and saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\FastAnalysisResults_merged.csv
#
# === Starting scoring process ===
# Starting scoring process with 6 workers using openrouter (google/gemini-2.5-flash-preview-05-20)...
#
# DEBUG Row 1: major_cluster_info = 'human large intestine'
# DEBUG Row 1: marker length = 338 chars
# DEBUG Row 1: annotation_history length = 7759 chars
# DEBUG: Calling LLM with provider=openrouter, model=google/gemini-2.5-flash-preview-05-20
# DEBUG: Prompt length: 10025 characters
# Retry 1/3 for row 4 due to None score
# Retry 1/3 for row 5 due to None score
# Retry 1/3 for row 2 due to None score
# DEBUG: LLM response length: 1428 characters
# DEBUG: LLM response (first 1000 chars): <reasoning>
# The single-cell annotation results provided by the agent are exceptionally well-executed, demonstrating a strong understanding of single-cell marker interpretation, biological context, and the importance of marker ranking.
#
# **Strengths:**
#
# 1.  **Comprehensive Marker Analysis:** The agent meticulously categorizes markers into "Key Functional Markers" and "Key Cell Type Markers." This structured approach allows for a holistic understanding of the cluster's characteristics beyond just cell lineage. Functional markers like granzymes (GZMH, GZMA, GZMB, GZMK, GZMM, PRF1, NKG7), chemokines (XCL2, XCL1, CCL4, CCL4L2, CCL5, IFNG), and immune checkpoints (TIGIT, TNFRSF9, LAG3) are correctly identified and interpreted as indicators of an activated, cytotoxic phenotype.
#
# 2.  **Accurate Cell Type Identification with Nuance:**
#     *   **Primary Identification (NK Cells):** The agent correctly identifies Natural Killer (NK) cells as the most prominent population. This is strongly supporte...
# DEBUG: Extracting from text (first 500 chars): <reasoning>
# The single-cell annotation results provided by the agent are exceptionally well-executed, demonstrating a strong understanding of single-cell marker interpretation, biological context, and the importance of marker ranking.
#
# **Strengths:**
#
# 1.  **Comprehensive Marker Analysis:** The agent meticulously categorizes markers into "Key Functional Markers" and "Key Cell Type Markers." This structured approach allows for a holistic understanding of the cluster's characteristics beyond just c...
# DEBUG: Found reasoning using pattern: Analysis:\s*(.*?)(?=Score:|$)
# DEBUG: Final extracted - Score: None, Reasoning length: 1140
# Retry 1/3 for row 1 due to None score
# DEBUG: Calling LLM with provider=openrouter, model=google/gemini-2.5-flash-preview-05-20
# DEBUG: Prompt length: 10025 characters
# Retry 1/3 for row 3 due to None score
# Retry 1/3 for row 6 due to None score
# Retry 2/3 for row 4 due to None score
# Retry 2/3 for row 2 due to None score
# Retry 2/3 for row 6 due to None score
# Retry 2/3 for row 3 due to None score
# Processed row 5: Score = 98
# DEBUG: LLM response length: 345 characters
# DEBUG: LLM response (first 1000 chars):
# <reasoning>
# The single-cell annotation results demonstrate an excellent understanding of single-cell biology and marker interpretation.
#
# **Strengths:**
#
# 1.  **Accurate Interpretation of Functional Markers:** The analysis correctly identifies key functional categories such as cytotoxicity (Granzymes, PRF1, NKG7), chemokines (XCL1/2, CCL4/5, IF...
# DEBUG: Extracting from text (first 500 chars):
# <reasoning>
# The single-cell annotation results demonstrate an excellent understanding of single-cell biology and marker interpretation.
#
# **Strengths:**
#
# 1.  **Accurate Interpretation of Functional Markers:** The analysis correctly identifies key functional categories such as cytotoxicity (Granzymes, PRF1, NKG7), chemokines (XCL1/2, CCL4/5, IF...
# DEBUG: Using entire text as reasoning
# DEBUG: Final extracted - Score: None, Reasoning length: 344
# Retry 2/3 for row 1 due to None score
# DEBUG: Calling LLM with provider=openrouter, model=google/gemini-2.5-flash-preview-05-20
# DEBUG: Prompt length: 10025 characters
# Processed row 4: Score = None
# Processed row 6: Score = None
# Processed row 2: Score = 98
# Processed row 3: Score = None
# DEBUG: LLM response length: 418 characters
# DEBUG: LLM response (first 1000 chars):
# :** Acknowledges the possibility<reasoning>
# The single-cell annotation results demonstrate a highly accurate, comprehensive, and well-justified analysis of the provided marker gene list. The agent effectively leverages the crucial information of marker ranking, which is paramount in single-cell RNA sequencing data analysis, to determine the most probable cell types and their relative contributions.
#
# **Strengths:**...
# DEBUG: Extracting from text (first 500 chars):
# :** Acknowledges the possibility<reasoning>
# The single-cell annotation results demonstrate a highly accurate, comprehensive, and well-justified analysis of the provided marker gene list. The agent effectively leverages the crucial information of marker ranking, which is paramount in single-cell RNA sequencing data analysis, to determine the most probable cell types and their relative contributions.
#
# **Strengths:**...
# DEBUG: Using entire text as reasoning
# DEBUG: Final extracted - Score: None, Reasoning length: 417
# Processed row 1: Score = None
#
# Scoring completed!
#
# Summary:
# Total rows: 6
# Successfully scored: 2
# Failed/Skipped: 4
# ✓ Scoring process completed
#
# === Generating main reports ===
# Report saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\report_cd8-positive alpha-beta t cell.html
# Report saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\report_intestinal crypt stem cell.html
# Report saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\report_intestinal enteroendocrine cell.html
# Report saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\report_monocyte.html
# Report saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\report_plasma cell.html
# Report saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\report_transit amplifying cell of large intestine.html
# Index page saved to CASSIA_large_intestine_human_20250603_004726\01_annotation_results\FastAnalysisResults.html
# Moved HTML report FastAnalysisResults.html to reports folder
# Moved HTML report report_cd8-positive alpha-beta t cell.html to reports folder
# Moved HTML report report_intestinal crypt stem cell.html to reports folder
# Moved HTML report report_intestinal enteroendocrine cell.html to reports folder
# Moved HTML report report_monocyte.html to reports folder
# Moved HTML report report_plasma cell.html to reports folder
# Moved HTML report report_transit amplifying cell of large intestine.html to reports folder
# ✓ Main reports generated
#
# === Analyzing low-scoring clusters ===
# Found 0 clusters with scores below 98:
# []
# Removed original file: FastAnalysisResults_full.csv
# Removed original file: FastAnalysisResults_summary.csv
#
# === Cell type analysis pipeline completed ===
# All results have been organized in the 'CASSIA_large_intestine_human_20250603_004726' folder:
#   - Annotation Results (CSV files): CASSIA_large_intestine_human_20250603_004726\01_annotation_results
#   - HTML Reports: CASSIA_large_intestine_human_20250603_004726\02_reports
#   - Annotation Boost Results: CASSIA_large_intestine_human_20250603_004726\03_boost_analysis

# %% [markdown]
# ### Step 2: Detailed Batch Analysis

# %%
output_name="intestine_detailed"

# %%
# Run batch analysis
CASSIA.runCASSIA_batch( 
    marker = unprocessed_markers,
    output_name = output_name,
    model = "google/gemini-2.5-flash-preview-05-20",
    tissue = "large intestine",
    species = "human",
    max_workers = 6,  # Matching cluster count
    n_genes = 50,
    additional_info = None,
    provider = "openrouter")
# Out:
# Processing input dataframe to get top markers
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing monocyte...
#
# Analyzing plasma cell...
#
# Analyzing transit amplifying cell of large intestine...
# Analysis for intestinal crypt stem cell completed.
# Analysis for plasma cell completed.
# Analysis for intestinal enteroendocrine cell completed.
# Analysis for transit amplifying cell of large intestine completed.
# Analysis for cd8-positive, alpha-beta t cell completed.
# Error decoding JSON: Invalid control character at: line 6 column 151 (char 715)
# monocyte generated an exception: Expecting value: line 1 column 1 (char 0)
# Retrying analysis for monocyte (attempt 2/2)...
# Error decoding JSON: Invalid control character at: line 6 column 151 (char 715)
# monocyte failed after 2 attempts with error: Expecting value: line 1 column 1 (char 0)
# monocyte failed: Expecting value: line 1 column 1 (char 0)
# All analyses completed. Results saved to 'intestine_detailed'.
# Two CSV files have been created:
# 1. intestine_detailed_full.csv (full data)
# 2. intestine_detailed_summary.csv (summary data)

# %%
output_name="intestine_detailed"

# %% [markdown]
# ### Step 3: Quality Scoring

# %%
# Run quality scoring
CASSIA.runCASSIA_score_batch(
    input_file = output_name + "_full.csv",
    output_file = output_name + "_scored.csv",
    max_workers = 6,
    model = "google/gemini-2.5-flash-preview-05-20",
    provider = "openrouter"
)

# Generate quality report
CASSIA.runCASSIA_generate_score_report(
    csv_path = output_name + "_scored.csv",
    index_name = output_name + "_report.html"
)
# Out:
# Starting scoring process with 6 workers using openrouter (google/gemini-2.5-flash-preview-05-20)...
# Processed row 6: Score = 98
# Processed row 3: Score = 98
# Processed row 2: Score = 98
# Processed row 5: Score = 98
# Processed row 4: Score = 95
# Processed row 1: Score = 98
#
# Scoring completed!
#
# Summary:
# Total rows: 6
# Successfully scored: 6
# Failed/Skipped: 0
# Report saved to .\report_cd8-positive alpha-beta t cell.html
# Report saved to .\report_intestinal crypt stem cell.html
# Report saved to .\report_intestinal enteroendocrine cell.html
# Report saved to .\report_monocyte.html
# Report saved to .\report_plasma cell.html
# Report saved to .\report_transit amplifying cell of large intestine.html
# Index page saved to .\intestine_detailed_report.html.html

# %% [markdown]
# ### Optional Step: Uncertainty Quantification
#
# This could be useful to study the uncertainty of the annotation, and potentially improve the accurracy.
#
# Note:This is step could be costy, since multiple iteration will be performed.

# %%
# Run multiple iterations
iteration_results = CASSIA.runCASSIA_batch_n_times(
    n=3,
    marker=unprocessed_markers,  # Changed from markers_unprocessed
    output_name=output_name + "_Uncertainty",  # Changed from paste0()
    model="google/gemini-2.5-flash-preview-05-20",
    provider="openrouter",
    tissue="large intestine",
    species="human",
    max_workers=6,
    batch_max_workers=3  # Conservative setting for API rate limits
)
# Out:
# Starting batch run 1/3
# Starting batch run 2/3
# Processing input dataframe to get top markers
# Starting batch run 3/3
# Processing input dataframe to get top markers
# Processing input dataframe to get top markers
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing monocyte...
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing plasma cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing monocyte...
#
# Analyzing transit amplifying cell of large intestine...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing plasma cell...
#
# Analyzing monocyte...
#
# Analyzing transit amplifying cell of large intestine...
#
# Analyzing plasma cell...
#
# Analyzing transit amplifying cell of large intestine...
# Analysis for transit amplifying cell of large intestine completed.
# Analysis for transit amplifying cell of large intestine completed.
# Analysis for plasma cell completed.
# Analysis for plasma cell completed.
# Analysis for transit amplifying cell of large intestine completed.
# Analysis for intestinal crypt stem cell completed.
# Analysis for intestinal crypt stem cell completed.
# Analysis for intestinal crypt stem cell completed.
# Analysis for monocyte completed.
# Analysis for plasma cell completed.
# Analysis for monocyte completed.
# Analysis for intestinal enteroendocrine cell completed.
# Analysis for monocyte completed.
# Analysis for cd8-positive, alpha-beta t cell completed.
# All analyses completed. Results saved to 'intestine_detailed_Uncertainty_2.json'.
# Two CSV files have been created:
# 1. intestine_detailed_Uncertainty_2_full.csv (full data)
# 2. intestine_detailed_Uncertainty_2_summary.csv (summary data)
# Finished batch run 3/3 in 23.17 seconds
# Batch run 3/3 completed and saved to intestine_detailed_Uncertainty_2.json
# Analysis for cd8-positive, alpha-beta t cell completed.
# Analysis for intestinal enteroendocrine cell completed.
# Analysis for intestinal enteroendocrine cell completed.
# All analyses completed. Results saved to 'intestine_detailed_Uncertainty_0.json'.
# Two CSV files have been created:
# 1. intestine_detailed_Uncertainty_0_full.csv (full data)
# 2. intestine_detailed_Uncertainty_0_summary.csv (summary data)
# Finished batch run 1/3 in 24.63 seconds
# Batch run 1/3 completed and saved to intestine_detailed_Uncertainty_0.json
# Analysis for cd8-positive, alpha-beta t cell completed.
# All analyses completed. Results saved to 'intestine_detailed_Uncertainty_1.json'.
# Two CSV files have been created:
# 1. intestine_detailed_Uncertainty_1_full.csv (full data)
# 2. intestine_detailed_Uncertainty_1_summary.csv (summary data)
# Finished batch run 2/3 in 24.82 seconds
# Batch run 2/3 completed and saved to intestine_detailed_Uncertainty_1.json
# All 3 batch runs completed in 24.82 seconds
# Organizing batch results...
# Processing cell type results...
#
# Processing cell type: cd8-positive, alpha-beta t cell
# Number of predictions: 3
# Number of valid predictions: 3
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: intestinal crypt stem cell
# Number of predictions: 3
# Number of valid predictions: 3
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: intestinal enteroendocrine cell
# Number of predictions: 3
# Number of valid predictions: 3
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: monocyte
# Number of predictions: 3
# Number of valid predictions: 3
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: plasma cell
# Number of predictions: 3
# Number of valid predictions: 3
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: transit amplifying cell of large intestine
# Number of predictions: 3
# Number of valid predictions: 3
# Starting the process of cell type batch variance analysis with openrouter...
# Unified results: result1:(Enteroendocrine Cell, L-cell),result2:(Enteroendocrine Cell, L-cell),result3:(Enteroendocri...
# Unified results: result1:(Intestinal Stem Cell, Lgr5+ Intestinal Stem Cell),result2:(Intestinal Stem Cell, Lgr5+ Inte...
# Unified results: result1:(Schwann Cells, Schwann Cells (Myelinating Or Non-Myelinating)),result2:(Schwann Cells, Schw...
# Unified results: result1:(Cytotoxic Lymphocyte, Cd8+ Effector/Cytotoxic T Cell),result2:(Cytotoxic Lymphocyte, Cd8+ E...
# Unified results: result1:(Plasma Cell, IgA Plasma Cell),result2:(Plasma Cell, IgA Plasma Cell),result3:(Plasma Cell, ...
# Unified results: result1:(Proliferating Cell, Enterocyte Progenitor / Transit-Amplifying (TA) Cell),result2:(Prolifer...
# Consensus judgment: ```json
# {
#   "final_results": [
#     "Schwann Cells",
#     "Schwann Cells (Myelinating Or Non-Myelinati...
# General celltype: Schwann Cells
# Sub celltype: Schwann Cells (Myelinating Or Non-Myelinating)
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# Consensus judgment: ```json
# {
#   "final_results": [
#     "Enteroendocrine Cell",
#     "L-cell"
#   ],
#   "possible_mixed_cellt...
# General celltype: Enteroendocrine Cell
# Sub celltype: L-cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# Consensus judgment: ```json
# {
#   "final_results": [
#     "Intestinal Stem Cell",
#     "Lgr5+ Intestinal Stem Cell"
#   ],
#   "...
# General celltype: Intestinal Stem Cell
# Sub celltype: Lgr5+ Intestinal Stem Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# Consensus judgment: <json>
# {
# "final_results": [
# "Cytotoxic Lymphocyte",
# "Cd8+ Effector/Cytotoxic T Cell"
# ],
# "possible_mi...
# General celltype: Cytotoxic Lymphocyte
# Sub celltype: Cd8+ Effector/Cytotoxic T Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# General celltype oncology: intestinal enteroendocrine progenitor
# Sub celltype oncology: L cone cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for intestinal enteroendocrine cell
# General celltype oncology: intestinal crypt stem cell
# Sub celltype oncology: intestinal crypt stem cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for intestinal crypt stem cell
# General celltype oncology: Schwann cell
# Sub celltype oncology: non-myelinating Schwann cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for monocyte
# Consensus judgment: <json>{
# "final_results": [
# "Plasma Cell",
# "IgA Plasma Cell"
# ],
# "possible_mixed_celltypes": [],
# "cons...
# General celltype: Plasma Cell
# Sub celltype: IgA Plasma Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# General celltype oncology: cytotoxic T cell
# Sub celltype oncology: CD8-positive, alpha-beta cytotoxic T cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for cd8-positive, alpha-beta t cell
# Consensus judgment: <json>{
# "final_results": [
# "Proliferating Cell",
# "Enterocyte Progenitor / Transit-Amplifying (TA) Ce...
# General celltype: Proliferating Cell
# Sub celltype: Enterocyte Progenitor / Transit-Amplifying (TA) Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# General celltype oncology: plasma cell
# Sub celltype oncology: IgA plasma cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for plasma cell
# General celltype oncology: cycling B cell
# Sub celltype oncology: transit amplifying cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for transit amplifying cell of large intestine
# Creating and saving results dataframe...
#
# Results saved to intestine_uncertainty.csv
# Results have been processed and saved to intestine_uncertainty

# %%
# Calculate similarity scores
similarity_scores = CASSIA.runCASSIA_similarity_score_batch(
    marker=unprocessed_markers,  # Changed from markers_unprocessed
    file_pattern=output_name + "_Uncertainty_*_full.csv",  # Changed from paste0()
    output_name="intestine_uncertainty",
    max_workers=6,
    model="google/gemini-2.5-flash-preview-05-20",
    provider="openrouter",
    main_weight=0.5,
    sub_weight=0.5
)
# Out:
# Results saved to intestine_uncertainty.csv
# Similarity analysis completed: intestine_uncertainty

# %% [markdown]
# ### Optional Step: Annotation Boost on Selected Cluster
#
# The monocyte cluster is sometimes annotated as mixed population of immune cell and neuron/glia cells.
#
# Here we use annotation boost agent to test these hypothesis in more detail.

# %%
output_name="intestine_detailed"

# Run validation plus for the high mitochondrial content cluster
CASSIA.runCASSIA_annotationboost(
    full_result_path = output_name + "_full.csv",
    marker = unprocessed_markers,
    output_name = "monocyte_annotationboost",
    cluster_name = "monocyte",
    major_cluster_info = "Human Large Intestine",
    num_iterations = 5,
    model = "google/gemini-2.5-flash-preview-05-20",
    provider = "openrouter",
    conversation_history_mode="final"
)
# Out:
# Using summarization agent to process conversation history for cluster monocyte
# Conversation history summarized using openrouter (11957 -> 1766 characters)
# Using conversation history for cluster monocyte (mode: final, 1766 characters)
# Iteration 1 completed.
# Iteration 2 completed.
# Iteration 3 completed.
# Iteration 4 completed.
# Final annotation completed in iteration 5.
# Raw conversation text saved to monocyte_annotationboost_raw_conversation.txt
# Raw conversation text saved to monocyte_annotationboost_raw_conversation.txt
# HTML report saved to monocyte_annotationboost_summary.html
# Summary report saved to monocyte_annotationboost_summary.html
# Summary report saved to monocyte_annotationboost_summary.html
# {'status': 'success',
#  'raw_text_path': 'monocyte_annotationboost_raw_conversation.txt',
#  'summary_report_path': 'monocyte_annotationboost_summary.html',
#  'execution_time': 79.11194586753845,
#  'analysis_text': 'Evaluation\nThe data continues to strongly support a neural crest-derived glial cell. The high expression of SOX10, PLP1, S100B, NGFR, CDH19, L1CAM, and MYOT are all consistent with this lineage. The persistent and high expression of MPZ, PMP22, and PRX, coupled with the absence of MBP (from previous data) and KROX20 (not in list), strongly points towards **non-myelinating Schwann cells**. The presence of neuronal-associated markers (SYP, SNAP25) with `pct.1` values less than 1.00, alongside high SPP1, SFRP5, WNT6, GFRA2, and LGR5, suggests a highly interactive, potentially reactive, or progenitor-like non-myelinating Schwann cell population. The low expression of CD44 and PROM1 argues against a broad progenitor state, but LGR5 is still high. The evidence is converging towards a specific type of non-myelinating Schwann cell.\n\ncelltype to check 1\n\n<check_genes>\nSOX10,PLP1,S100B,MPZ,PMP22,PRX,GFAP\n</check_genes>\n\n<reasoning>\nTo finalize the distinction between non-myelinating Schwann cells and EGCs, we need to confirm the absence of canonical EGC markers like GFAP. While both are neural crest-derived glia, the consistent high expression of MPZ, PMP22, and PRX, in the absence of MBP, is a hallmark of non-myelinating Schwann cells. If GFAP remains low or absent, it would strongly support non-myelinating Schwann cells over typical EGCs. SOX10, PLP1, and S100B are expressed by both, but the specific myelin-related protein signature is more definitive for non-myelinating Schwann cells.\n</reasoning>\n\nhypothesis to check 2\n\n<check_genes>\nSYP,SNAP25,NRXN1,NRXN3,SOX10,PLP1,MYOT\n</check_genes>\n\n<reasoning>\nThe persistent expression of neuronal-associated markers (SYP, SNAP25, NRXN1, NRXN3) with `pct.1` values less than 1.00 suggests a subset of cells or a specific interaction. We need to determine if this represents a true mixed population (e.g., doublets of non-myelinating Schwann cells and neurons) or a highly specialized non-myelinating Schwann cell that expresses these genes due to intimate neuro-glial interactions. If the expression of these neuronal markers is restricted to a small fraction of cells, it could indicate contamination. If they are consistently co-expressed within the same cells that also express high levels of non-myelinating Schwann cell markers (SOX10, PLP1, MYOT), it would suggest a unique functional state of these Schwann cells.\n</reasoning>\n\nhypothesis to check 3\n\n<check_genes>\nSPP1,SFRP5,WNT6,GFRA2,LGR5,NGFR,CDH19\n</check_genes>\n\n<reasoning>\nThe high expression of SPP1, SFRP5, WNT6, GFRA2, LGR5, NGFR, and CDH19 suggests a highly active and interactive non-myelinating Schwann cell population, potentially involved in development, regeneration, or a reactive state. SPP1 is often associated with reactive glia and cell adhesion. SFRP5 and WNT6 are involved in Wnt signaling, crucial for development and plasticity. GFRA2 and NGFR are involved in neurotrophic signaling. LGR5 indicates a potential stem/progenitor-like capacity or a specific functional subset. This check aims to characterize the functional state and potential plasticity of these non-myelinating Schwann cells.\n</reasoning>\nFINAL ANNOTATION COMPLETED\nThe final cell type is **Non-myelinating Schwann Cells**.\nConfidence level: **High**.\nKey markers supporting your conclusion: The robust and consistent expression of SOX10, PLP1, S100B, NGFR, CDH19, L1CAM, MYOT, combined with the specific myelin-related protein signature of high MPZ, PMP22, and PRX, and critically, the *absence* of MBP and GFAP (from previous checks), strongly points to non-myelinating Schwann cells. The presence of neuronal-associated markers (SYP, SNAP25, NRXN1, NRXN3) is interpreted as reflecting the intimate neuro-glial interactions characteristic of these cells in the enteric nervous system, rather than a neuronal identity or significant contamination, especially given the high expression of adhesion molecules and signaling pathway compon ...

# %% [markdown]
# ### Optional Step: Retrieve Augmented Generation
#
# This is particularly useful if you have a very specific and detialed annottaion to work with. It can significantly imrpove the granularity and accuracy of the annotation. It automatically extract marker information and genearte a report as additional informatyion for default CASSIA pipeline.

# %% [markdown]
# Intsall the package

# %%
# !pip install cassia-rag

# %%
# !pip install cassia-rag
from cassia_rag import run_complete_analysis
import os
# Out:
# Running cells with 'cassia_rag (Python 3.11.10)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\anaconda3\envs\cassia_rag ipykernel --update-deps --force-reinstall'

# %% [markdown]
# Set up the API keys if you have not done so.

# %%
os.environ["ANTHROPIC_API_KEY"] = "your-anthropic-key"
os.environ["OPENAI_API_KEY"] = "your-openai-key"

# %% [markdown]
# Run the wrapper function to trigger a multiagent pipeline.

# %%
run_complete_analysis(
        tissue_type="Liver", # tissue you are analyzing
        target_species="Tiger", # species you are analyzing
        reference_species="Human", # either Human or mouse, if other species, then use Human instead of mouse
        model_choice='claude', # either claude or gpt, highly recommend claude
        compare=True,  # if you want to compare with reference species, for example fetal vs human, then set to True
        db_path="~/Canonical_Marker (1).csv", # path to the database
        max_workers=8
)

# %% [markdown]
# All the outputs (intermediate and final) are saved as a txt file in the "TissueType_Species" folder. In our example, it is Liver_Tiger folder.
# Final output is in summary_clean.txt file. And the content in this file can be used as additional information in CASSIA pipeline later.
#
# There are also some other files in the folder, which are intermediate outputs.
# Use the tutorial input as example, the files are:
# 1. liver_tiger_marker_analysis.txt # marker analysis and interpretation from the database
# 2. final_ontology.txt # ontology related to the tissue type and target species
# 3. cell_type_patterns_claude.txt # cell type patterns analysis from the
# 4. summary.txt # raw summary file
# 5. additional_considerations.txt # additional considerations if we have different species than reference species.

# %% [markdown]
# ### Optional Step: Compare the Subtypes Using Multiple LLMs
#
# This agent can be used after you finish the default CASSIA pipeline, and are still unsure about a celltype. You can use this agent to get a more confident subtype annotation. Here we use the Plasma Cells cluster as examples. To distinguish if it is more like a general plasma cell or other celltypes.

# %%
# The marker here are copy from CASSIA's previous results.
marker = "IGLL5, IGLV6-57, JCHAIN, FAM92B, IGLC3, IGLC2, IGHV3-7, IGKC, TNFRSF17, IGHG1, AC026369.3, IGHV3-23, IGKV4-1, IGKV1-5, IGHA1, IGLV3-1, IGLV2-11, MYL2, MZB1, IGHG3, IGHV3-74, IGHM, ANKRD36BP2, AMPD1, IGKV3-20, IGHA2, DERL3, AC104699.1, LINC02362, AL391056.1, LILRB4, CCL3, BMP6, UBE2QL1, LINC00309, AL133467.1, GPRC5D, FCRL5, DNAAF1, AP002852.1, AC007569.1, CXorf21, RNU1-85P, U62317.4, TXNDC5, LINC02384, CCR10, BFSP2, APOBEC3A, AC106897.1"

CASSIA.compareCelltypes(
    tissue = "large intestine",
    celltypes = ["Plasma Cells", "IgA-secreting Plasma Cells", "IgG-secreting Plasma Cells", "IgM-secreting Plasma Cells"],
    marker_set = marker,
    species = "human",
    output_file = "plasama_cell_subtype.html"
)
# Out:
# Model: anthropic/claude-3.7-sonnet
# Extracted scores: {'Plasma Cells': {'score': '95', 'reasoning': "The marker set strongly indicates plasma cells. Multiple immunoglobulin genes are highly ranked, including IGLL5, IGLV6-57, IGLC3, IGLC2, IGHV3-7, IGKC, IGHV3-23, IGKV4-1, IGKV1-5, IGLV3-1, and IGLV2-11. These represent various light chain (kappa and lambda) and heavy chain components that are characteristic of antibody-producing plasma cells.\n\nAdditionally, JCHAIN (J chain protein) is highly ranked (#3), which is crucial for multimerization of IgA and IgM in plasma cells. MZB1 (Marginal Zone B and B1 Cell-Specific Protein) is a key marker of plasma cell differentiation. TNFRSF17 (also known as BCMA) is a receptor highly expressed in plasma cells that promotes their survival.\n\nOther supportive markers include DERL3 (involved in ER-associated degradation in secretory cells), MZB1 (required for IgM assembly), and TXNDC5 (protein disulfide isomerase involved in antibody folding). The presence of FCRL5 (Fc Receptor-Like 5) further supports the plasma cell identity as it's expressed on mature B cells and plasma cells.\n\nThis marker profile strongly represents plasma cells in general, without specifically distinguishing which immunoglobulin class they secrete, though multiple classes are represented in the marker set."}, 'IgA-secreting Plasma Cells': {'score': '90', 'reasoning': "The marker set contains strong evidence for IgA-secreting plasma cells specifically. Most importantly, IGHA1 (ranked #15) and IGHA2 (ranked #26) are present - these are the heavy chain genes specifically for IgA1 and IgA2, the two subtypes of IgA antibodies that are particularly abundant in mucosal tissues like the large intestine.\n\nAdditionally, JCHAIN (ranked #3) is particularly important for IgA plasma cells as it's crucial for the formation of dimeric IgA that can be transported across mucosal epithelium. CCR10 (ranked #47) is also notable as it encodes a chemokine receptor that guides IgA-secreting plasma cells to mucosal tissues, particularly the intestine.\n\nThe presence of multiple immunoglobulin light chain genes (IGLV6-57, IGLC3, IGLC2, IGKC, etc.) along with the above specific markers strongly indicates IgA-secreting plasma cells. The combination of IGHA1, IGHA2, JCHAIN, and CCR10 is quite specific to IgA plasma cells found in intestinal mucosa.\n\nThe high ranking of IGHA1 and the presence of IGHA2 in a marker set from the large intestine particularly strengthens the case for IgA-secreting plasma cells, as these are the predominant antibody-secreting cells in intestinal tissue."}, 'IgG-secreting Plasma Cells': {'score': '75', 'reasoning': 'The marker set shows evidence supporting IgG-secreting plasma cells, though not as strongly as for general plasma cells. IGHG1 (ranked #10) and IGHG3 (ranked #20) are specific heavy chain genes for the IgG1 and IgG3 subclasses of IgG, indicating the presence of IgG-secreting cells.\n\nThe marker profile includes the expected immunoglobulin light chain genes (IGLV6-57, IGLC3, IGLC2, IGKC, etc.) that would be present in any antibody-producing plasma cell. The general plasma cell markers are also present: MZB1, TNFRSF17 (BCMA), and DERL3.\n\nHowever, the marker set lacks some characteristics that might be more specific to IgG plasma cells. For example, JCHAIN (J chain) is highly ranked (#3), but this is more characteristic of IgA and IgM secreting cells than IgG cells. Additionally, the presence of CCR10 (ranked #47) suggests mucosal homing, which is more associated with IgA than IgG plasma cells.\n\nWhile IGHG1 and IGHG3 clearly indicate some IgG-secreting cells in the population, their relative rankings compared to IgA-related genes (with IGHG1 at #10 versus IGHA1 at #15) and the presence of mucosal-associated markers suggest this may not be the predominant plasma cell type in this marker set from large intestine tissue.'}, 'IgM-secreting Plasma Cells': {'score': '65', 'reasoning': "The marker set provides moderate evidence for IgM-secreti ...
# --------------------------------------------------
# Model: openai/o4-mini-high
# Extracted scores: {'Plasma Cells': {'score': '100', 'reasoning': 'This marker set is overwhelmingly dominated by immunoglobulin chain transcripts (IGLL5, IGLV6-57, IGLC3, IGLC2, IGHV3-7, IGKC, IGHV3-23, IGKV4-1, IGKV1-5, IGLV3-1, IGLV2-11, IGHV3-74, IGKV3-20, etc.), spanning both heavy and light chains across multiple isotypes. Key plasma cell–specific genes are also present: JCHAIN (essential for polymeric Ig assembly), TNFRSF17 (BCMA, critical for plasma cell survival), MZB1 (ER chaperone for Ig folding), FCRL5 (Fc receptor–like plasma cell marker), DERL3 and TXNDC5 (ER stress/chaperone machinery). CCR10 indicates mucosal homing often seen in gut-resident plasma cells. The high-ranking of these markers, together with the breadth of Ig transcripts, fits the canonical profile of antibody-secreting plasma cells rather than earlier B cell stages or other immune cell types.'}, 'IgA-secreting Plasma Cells': {'score': '85', 'reasoning': 'The presence of both IGHA1 and IGHA2, together with JCHAIN, strongly supports an IgA-secreting phenotype, since JCHAIN is required for dimeric IgA secretion and CCR10 directs gut homing of IgA plasma cells. Many of the light-chain variable genes and TNFRSF17/MZB1/FCRL5 are also consistent with mature plasma cells. However, this set also includes high levels of IGHG1, IGHG3 and IGHM transcripts, which dilute specificity for an exclusive IgA-secreting population. Overall, there is a robust IgA signature and mucosal homing markers but not an IgA-only profile.'}, 'IgG-secreting Plasma Cells': {'score': '75', 'reasoning': 'IGHG1 and IGHG3 are clearly represented, indicating class-switched IgG production, and the general plasma cell machinery (JCHAIN, TNFRSF17, MZB1, FCRL5) supports an antibody-secreting phenotype. However, IgG-secreting cells typically downregulate JCHAIN and do not express CCR10 at high levels, whereas both appear here. Furthermore, IGHA1/2 and IGHM transcripts are also present at substantial rank, reducing specificity for an IgG-only subset. The marker profile is compatible with IgG secretion but mixed with other isotypes.'}, 'IgM-secreting Plasma Cells': {'score': '60', 'reasoning': 'The marker set includes IGHM and JCHAIN, which are necessary for pentameric IgM secretion, and core plasma cell markers (TNFRSF17, MZB1, FCRL5). However, there is only a single IGHM entry versus multiple IGHA and IGHG genes, suggesting that class-switched isotypes dominate this profile. CCR10 (mucosal homing) and high levels of IGHA/IGHG are not typical for early or long-lived IgM-only plasma cells. Thus, the evidence for an IgM-restricted plasma cell population is relatively weak.'}}
# --------------------------------------------------
# Model: google/gemini-2.5-pro-preview
# Extracted scores: {'Plasma Cells': {'score': '98', 'reasoning': "This marker set is highly indicative of plasma cells. Here's why:\n1.  **Immunoglobulin (Ig) Gene Expression:** The list is replete with genes encoding immunoglobulin heavy chains (IGHV3-7, IGHG1, IGHV3-23, IGHA1, IGHG3, IGHV3-74, IGHM, IGHA2) and light chains (IGLL5, IGLV6-57, IGLC3, IGLC2, IGKC, IGKV4-1, IGKV1-5, IGLV3-1, IGLV2-11, IGKV3-20). High-level expression of Ig genes is the defining characteristic of antibody-secreting plasma cells.\n2.  **JCHAIN (Joining Chain):** Ranked 3rd, JCHAIN is crucial for the polymerization of IgA (to form dimers) and IgM (to form pentamers). Its high expression strongly supports the presence of plasma cells, particularly those secreting polymeric immunoglobulins.\n3.  **TNFRSF17 (BCMA - B-Cell Maturation Antigen):** Ranked 9th, TNFRSF17 is a key survival receptor for plasma cells and is considered a canonical plasma cell marker.\n4.  **MZB1 (Marginal Zone B And B-1 Cell Specific Protein):** Ranked 19th, MZB1 is expressed in plasma cells and plays a role in antibody secretion by regulating calcium homeostasis in the ER.\n5.  **XBP1 (not listed, but implied):** While not explicitly listed, the high Ig production machinery markers (like DERL3, TXNDC5 involved in ER proteostasis) are consistent with high XBP1 activity, a master regulator of plasma cell differentiation and function. DERL3 is involved in ER-associated degradation (ERAD), important for handling misfolded proteins during high Ig production. TXNDC5 is a PDI family member, crucial for disulfide bond formation in immunoglobulins.\n6.  **Lack of B-cell specific markers (e.g., CD19, CD20/MS4A1, PAX5):** While this list represents positive markers, the strong plasma cell signature suggests these cells have differentiated beyond the B-cell stage where these markers would be downregulated.\n7.  **FCRL5 (Fc Receptor Like 5):** Ranked 38th, FCRL5 can be expressed on a subset of memory B cells and plasma cells, often associated with tissue-resident plasma cells.\n\nThe sheer abundance and high ranking of Ig genes, JCHAIN, and TNFRSF17 unequivocally point to a plasma cell identity."}, 'IgA-secreting Plasma Cells': {'score': '90', 'reasoning': 'This marker set strongly supports the presence of IgA-secreting plasma cells.\n1.  **IGHA1 and IGHA2:** These genes encode the constant regions of the IgA1 and IgA2 heavy chains, respectively. IGHA1 is ranked 15th and IGHA2 is ranked 26th. Their presence is definitive for IgA production.\n2.  **JCHAIN:** Ranked 3rd, JCHAIN is essential for the dimerization of IgA, which is the predominant form of secreted IgA in mucosal tissues like the large intestine. Its very high rank strongly bolsters the IgA-secreting phenotype.\n3.  **Context of Large Intestine:** The large intestine is a major site of mucosal immunity, where IgA is the primary antibody isotype responsible for neutralizing pathogens and toxins at the epithelial barrier. Thus, a prominent IgA-secreting plasma cell population is expected.\n4.  **CCR10:** Ranked 47th, CCR10 is a chemokine receptor expressed on IgA-secreting plasma cells that helps them home to mucosal tissues, including the gut.\n\nWhile other Ig isotypes are present (see below), the combination of IGHA1, IGHA2, highly ranked JCHAIN, the presence of CCR10, and the origin (large intestine) makes a compelling case for a significant population of IgA-secreting plasma cells.'}, 'IgG-secreting Plasma Cells': {'score': '80', 'reasoning': "This marker set clearly indicates the presence of IgG-secreting plasma cells.\n1.  **IGHG1 and IGHG3:** These genes encode the constant regions of IgG1 and IgG3 heavy chains, respectively. IGHG1 is ranked 10th and IGHG3 is ranked 20th. Their presence and relatively high ranking are direct evidence of IgG production.\n2.  **Context of Large Intestine:** While IgA is dominant in mucosal secretions, IgG-secreting plasma cells are also present in the lamina propria of the gut, contributing to  ...
# --------------------------------------------------
# Results saved to plasama_cell_subtype.html
# HTML report saved to plasama_cell_subtype.html

# %% [markdown]
# ### Optional Step: Subclustering
#
#
# This agent can be used to study subclustered population, such as a T cell population or a Fibroblast cluster. We recommend to apply the default cassia first, and on a target cluster, apply Seurat pipeline to subcluster the cluster and get the findallmarke results to be used here. Here we present the results for the cd8-positive, alpha-beta t cell cluster as example. This cluster is a cd8 population mixed with other celltypes.

# %%
##below are R code or can be done in Scanpy too

# large=readRDS("/Users/xie227/Downloads/seurat_object.rds")
# # Extract CD8+ T cells
# cd8_cells <- subset(large, cell_ontology_class == "cd8-positive, alpha-beta t cell")
# # Normalize and identify variable features
# cd8_cells <- NormalizeData(cd8_cells)
# cd8_cells <- FindVariableFeatures(cd8_cells, selection.method = "vst", nfeatures = 2000)
# # Scale data and run PCA
# all.genes <- rownames(cd8_cells)
# cd8_cells <- ScaleData(cd8_cells, features = all.genes)
# cd8_cells <- RunPCA(cd8_cells, features = VariableFeatures(object = cd8_cells),npcs = 30)
# # Run clustering (adjust resolution and dims as needed based on elbow plot)
# cd8_cells <- FindNeighbors(cd8_cells, dims = 1:20)
# cd8_cells <- FindClusters(cd8_cells, resolution = 0.3)
# # Run UMAP
# cd8_cells <- RunUMAP(cd8_cells, dims = 1:20)
# # Create visualization plots
# p1 <- DimPlot(cd8_cells, reduction = "umap", label = TRUE) +
#   ggtitle("CD8+ T Cell Subclusters")
# # Find markers for each subcluster
# cd8_markers <- FindAllMarkers(cd8_cells,
#                             only.pos = TRUE,
#                             min.pct = 0.1,
#                             logfc.threshold = 0.25)
# cd8_markers=cd8_markers %>% filter(p_val_adj<0.05)
# write.csv(cd8_markers, "cd8_subcluster_markers.csv")

CASSIA.runCASSIA_subclusters(marker = subcluster_results,
    major_cluster_info = "cd8 t cell",
    output_name = "subclustering_results",
    model = "google/gemini-2.5-flash-preview-05-20",
    provider = "openrouter")
# Out:
# Processing input dataframe to get top 50 markers
# Analysis text is already in structured format (list of 6 dictionaries)
# [{'Key marker': 'IL7R, KLRB1, CD2, CD8A, CD8B', 'Explanation': 'IL7R (CD127) is a key marker for naive and memory T cells, indicating their ability to respond to IL-7 for survival and proliferation. KLRB1 (CD161) is expressed on a subset of T cells, including NK T cells and some CD8+ T cells, often associated with innate-like functions. CD2 is a pan-T cell marker. CD8A and CD8B are coreceptors defining CD8+ T cells. The presence of IL7R and KLRB1, along with general CD8 markers, suggests a less differentiated or innate-like CD8 T cell population.', 'Most likely top2 cell types': ['Naive CD8+ T cells', 'Innate-like CD8+ T cells (e.g., MAIT cells or NK-like CD8+ T cells)']}, {'Key marker': 'HAVCR2, TIGIT, KLRC2, KLRC3, IKZF2', 'Explanation': 'HAVCR2 (TIM-3) and TIGIT are well-known immune checkpoint receptors, often upregulated on exhausted or dysfunctional T cells in chronic infections and cancer. KLRC2 (NKG2C) and KLRC3 (NKG2E) are C-type lectin receptors typically found on NK cells and a subset of CD8+ T cells, particularly those with an innate-like or adaptive NK cell phenotype. IKZF2 (Helios) is a transcription factor associated with regulatory T cells but can also be expressed in activated or exhausted effector T cells. The combination of exhaustion markers and NK-like receptors points towards a highly activated, potentially exhausted, or terminally differentiated effector CD8 T cell population.', 'Most likely top2 cell types': ['Exhausted CD8+ T cells', 'Terminally differentiated effector CD8+ T cells (TEMRA)']}, {'Key marker': 'GZMK, KLRG1, EOMES, GZMH, PRF1, NKG7, CCL3, CST7', 'Explanation': 'GZMK, GZMH, PRF1 (Perforin), and NKG7 are all key components of the cytolytic machinery of cytotoxic T lymphocytes (CTLs). KLRG1 is a marker of terminal differentiation and senescence in T cells, often found on highly cytotoxic effector cells. EOMES is a transcription factor crucial for the development and function of effector and memory CD8+ T cells, particularly those with high cytotoxic potential. CCL3 is a chemokine produced by activated T cells. CST7 (Cystatin F) is an inhibitor of cysteine proteases, also associated with cytotoxic function. This set of markers strongly indicates a highly cytotoxic and terminally differentiated effector population.', 'Most likely top2 cell types': ['Cytotoxic effector CD8+ T cells', 'Terminally differentiated effector memory CD8+ T cells (TEMRA)']}, {'Key marker': 'HOXD13, CDX2, DLL4, PPARG, MUC4', 'Explanation': "This cluster presents a very unusual set of markers for T cells, as many of these genes (HOXD13, CDX2, DLL4, PPARG, MUC4) are typically associated with epithelial development, gut differentiation, or mesenchymal stem cells, and are not canonical T cell markers. HOXD13 and CDX2 are homeobox transcription factors involved in developmental patterning, particularly in the gut. DLL4 is a Notch ligand involved in cell fate determination and angiogenesis. PPARG is a nuclear receptor involved in adipogenesis and inflammation. MUC4 is a mucin protein. The presence of these markers in a CD8 T cell cluster suggests either a very rare, highly specialized, or perhaps aberrantly expressed phenotype, or potentially a contamination/misannotation issue. Given the context of CD8 T cells, it's highly unlikely these are typical T cell subsets. If forced to interpret within a T cell context, it might imply a very specific tissue-resident or developmentally influenced subset, but this is speculative.", 'Most likely top2 cell types': ['Atypical/Contaminated CD8+ T cell cluster (potential misannotation or rare, uncharacterized subset)', 'CD8+ T cells with aberrant developmental gene expression (e.g., due to specific tissue microenvironment or disease state)']}, {'Key marker': 'GNLY, KIR2DL4, KLRF1, ITGAX, FCER1G, TYROBP', 'Explanation': 'GNLY (Granulysin) is a cytotoxic protein found in the granules of CTLs and NK cells. KIR2DL4 (Killer cell immunoglobulin-like receptor, two domains, long cytoplasmic tail,  ...
# Results have been written to subclustering_results.csv

# %% [markdown]
# It is recommend to run the CS score for the subclustering to get a more confident answer.

# %%
CASSIA.runCASSIA_n_subcluster(
    n=5, 
    marker=subcluster_results,
    major_cluster_info="cd8 t cell", 
    base_output_name="subclustering_results_n",
    model="google/gemini-2.5-flash-preview-05-20",
    temperature=0,
    provider="openrouter",
    max_workers=5,
    n_genes=50
)
# Out:
# Processing input dataframe to get top 50 markers
# Processing input dataframe to get top 50 markers
# Processing input dataframe to get top 50 markers
# Processing input dataframe to get top 50 markers
# Processing input dataframe to get top 50 markers
# Analysis text is already in structured format (list of 6 dictionaries)
# Results for iteration 3 have been written to subclustering_results_n_3.csv
# Analysis text is already in structured format (list of 6 dictionaries)
# Results for iteration 5 have been written to subclustering_results_n_5.csv
# Analysis text is already in structured format (list of 6 dictionaries)
# Results for iteration 2 have been written to subclustering_results_n_2.csv
# Analysis text is already in structured format (list of 6 dictionaries)
# Analysis text is already in structured format (list of 6 dictionaries)
# Results for iteration 4 have been written to subclustering_results_n_4.csv
# Results for iteration 1 have been written to subclustering_results_n_1.csv

# %%
# Calculate similarity scores
CASSIA.runCASSIA_similarity_score_batch(
    marker = subcluster_results,
    file_pattern = "subclustering_results_n_*.csv",
    output_name = "subclustering_uncertainty",
    max_workers = 6,
    model = "google/gemini-2.5-flash-preview-05-20",
    provider = "openrouter",
    main_weight = 0.5,
    sub_weight = 0.5
)
# Out:
# Organizing batch results...
# Processing cell type results...
#
# Processing cell type: 0
# Number of predictions: 5
# Number of valid predictions: 5
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: 1
# Number of predictions: 5
# Number of valid predictions: 5
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: 2
# Number of predictions: 5
# Number of valid predictions: 5
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: 3
# Number of predictions: 5
# Number of valid predictions: 5
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: 4
# Number of predictions: 5
# Number of valid predictions: 5
# Starting the process of cell type batch variance analysis with openrouter...
#
# Processing cell type: 5
# Number of predictions: 5
# Number of valid predictions: 5
# Starting the process of cell type batch variance analysis with openrouter...
# Unified results: result1:(Cytotoxic Effector Cd8+ T Cell, Terminally Differentiated Effector Memory Cd8+ T Cell (TEMR...
# Unified results: result1:(Atypical/Contaminated Cd8+ T Cell Cluster, Cd8+ T Cell),result2:(Atypical/Contaminated Cd8+...
# Unified results: result1:(Naive Cd8+ T Cell, Innate-like Cd8+ T Cell),result2:(Naive Cd8+ T Cell, Innate-like Cd8+ T ...
# Unified results: result1:('Nk-like Cd8+ T Cell', 'Innate-like Cd8+ T Cell'),result2:('Nk-like Cd8+ T Cell', 'Innate-l...
# Unified results: result1:(Atypical/Contaminated Cd8+ T Cell Cluster, Cd8+ T Cell With Mesenchymal-Like Or Development...
# Unified results: result1:(Exhausted Cd8+ T Cell, Terminally Differentiated Effector Cd8+ T Cell (Temra)),result2:(Exh...
# Consensus judgment: <json>
# {
#   "final_results": [
#     "Naive Cd8+ T Cell",
#     "Innate-like Cd8+ T Cell"
#   ],
#   "possibl...
# General celltype: Naive Cd8+ T Cell
# Sub celltype: Innate-like Cd8+ T Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# Consensus judgment: <json>
# {
# "final_results": [
# "Cytotoxic Effector Cd8+ T Cell",
# "Terminally Differentiated Effector Me...
# General celltype: Cytotoxic Effector Cd8+ T Cell
# Sub celltype: Terminally Differentiated Effector Memory Cd8+ T Cell (TEMRA)
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# Consensus judgment: <json>
# {
#   "final_results": [
#     "Atypical/Contaminated Cd8+ T Cell Cluster",
#     "Cd8+ T Cell"
#   ]...
# General celltype: Atypical/Contaminated Cd8+ T Cell Cluster
# Sub celltype: Cd8+ T Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# General celltype oncology: naive thymus-derived CD8-positive, alpha-beta T cell
# Sub celltype oncology: innate effector T cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for 0
# General celltype oncology: CD8-positive, alpha-beta cytotoxic T cell
# Sub celltype oncology: effector memory CD8-positive, alpha-beta T cell, terminally differentiated
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for 2
# Consensus judgment: <json>
# {
#   "final_results": [
#     "Nk-like Cd8+ T Cell",
#     "Innate-like Cd8+ T Cell"
#   ],
#   "possi...
# General celltype: Nk-like Cd8+ T Cell
# Sub celltype: Innate-like Cd8+ T Cell
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# General celltype oncology: granzyme K-associated CD8 T cell
# Sub celltype oncology: granzyme H-associated CD8 T cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for 3
# Consensus judgment: <json>
# {
#   "final_results": [
#     "Exhausted Cd8+ T Cell",
#     "Terminally Differentiated Effector C...
# General celltype: Exhausted Cd8+ T Cell
# Sub celltype: Terminally Differentiated Effector Cd8+ T Cell (Temra)
# Mixed types: []
# Consensus score (LLM): 1.0
# LLM generated consensus score: 100
# General celltype oncology: CD4-negative, CD8-negative type I NK T cell
# Sub celltype oncology: innate effector T cell
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for 4
# General celltype oncology: exhausted T cell
# Sub celltype oncology: effector memory CD8-positive, alpha-beta T cell, terminally differentiated
# Mixed types oncology: []
# Consensus score (Oncology): 1.0
# Processing successful for 1
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Optional Step: Annotation Boost with Additional Task
#
# This can be used to study a given problem related to a cluster, such as infer the state of a cluster. Here we use the cd8-positive, alpha-beta t cell as an example. Note that the performance of this agent has not been benchmarked, so please be cautious with the results.

# %%
#only openrouter is supported as provider now.

CASSIA.runCASSIA_annotationboost_additional_task(
    full_result_path = output_name + "_full.csv",  # Changed from paste0() to Python string concatenation
    marker = unprocessed_markers,
    output_name = "T_cell_state",
    cluster_name = "cd8-positive, alpha-beta t cell",  # Cluster with high mitochondrial content
    major_cluster_info = "Human Large Intestine",
    num_iterations = 5,
    model = "anthropic/claude-3.5-sonnet",
    additional_task = "infer the state of this T cell cluster"
)
# Out:
# Using summarization agent to process conversation history for cluster cd8-positive, alpha-beta t cell
# Conversation history summarized using openrouter (10978 -> 1331 characters)
# Using conversation history for cluster cd8-positive, alpha-beta t cell (mode: final, 1331 characters)
# Iteration 1 completed.
# Iteration 2 completed.
# Final annotation completed in iteration 3.
# Raw conversation text saved to T_cell_state_raw_conversation.txt
# Raw conversation text saved to T_cell_state_raw_conversation.txt
# HTML report saved to T_cell_state_summary.html
# Summary report saved to T_cell_state_summary.html
# Summary report saved to T_cell_state_summary.html
# {'status': 'success',
#  'raw_text_path': 'T_cell_state_raw_conversation.txt',
#  'summary_report_path': 'T_cell_state_summary.html',
#  'execution_time': 51.82601761817932,
#  'analysis_text': 'Based on all available data, I am now ready to make a final determination.\n\nFINAL ANALYSIS COMPLETED\n\nGeneral Cell Type: Natural Killer (NK) Cells\nSpecific Subtype: CD56bright tissue-resident NK cells\nConfidence Level: High\n\nKey Evidence:\n1. NK Cell Identity (Very Strong Evidence):\n- High NCAM1/CD56 expression (log2FC = 7.13, 81% positive)\n- NK receptor repertoire (KLRC2, KLRK1, KLRC4, KLRD1)\n- Absence of T cell markers (CD3D/E negative)\n- Strong IL2RB expression (characteristic of NK cells)\n\n2. CD56bright Subtype Classification:\n- High CD27 expression (log2FC = 3.91, 81% positive)\n- Strong chemokine production (XCL1, XCL2, CCL4, CCL5)\n- High NCAM1/CD56 expression\n- Cytokine-producing profile\n\n3. Tissue Residency/State Analysis:\n- CXCR6 positive (log2FC = 2.08)\n- Activated cytotoxic state (multiple granzymes, PRF1)\n- Immunomodulatory phenotype (chemokine production)\n\nState Analysis:\n1. Activation Status: Highly Activated\n- Multiple activation markers (TNFRSF9)\n- Strong cytokine/chemokine production\n- Full cytotoxic machinery expression\n\n2. Functional State: \n- Armed cytotoxic effector (GZMA, GZMB, GZMH, GZMK, GZMM, PRF1)\n- Active immunomodulator (chemokine production)\n- Tissue-resident phenotype (CXCR6+)\n\n3. Regulatory Status:\n- Expression of regulatory receptors (TIGIT, LAG3)\n- Balance of activating and inhibitory NK receptors\n\nAlternative Possibilities:\nWhile confidence is high for NK cell identity, there could be some heterogeneity in the population, particularly in terms of activation states. However, the core identity as CD56bright tissue-resident NK cells is well-supported.\n\nClinical/Biological Relevance:\nThese cells appear to be tissue-resident NK cells with both cytotoxic and immunomodulatory functions, typical of those found in mucosal tissues like the large intestine. Their phenotype suggests active surveillance and immune response roles in the tissue microenvironment.\n\nThe high confidence level is based on:\n1. Clear NK cell marker pattern\n2. Distinct absence of T cell markers\n3. Coherent functional profile\n4. Tissue-appropriate phenotype\n5. Consistent expression patterns across multiple marker categories'}
